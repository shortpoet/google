# %%
from pprint import pprint

# %%
from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import base64
# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']

# %%
class Representer():
    def __repr__(self):
        return repr(vars(self))

# %%
class Message(Representer):
    def __init__(self, message_id='', thread_id='', label_ids='', date='', from_='',\
                 received='', received_SPF='', subject='', list_unsubscribe='',\
                 size_estimate='', history_id='', internal_date='', parts=list()):
        self.message_id = message_id
        self.thread_id = thread_id
        self.label_ids = label_ids
        self.date = date
        self.from_ = from_
        self.received = received
        self.received_SPF = received_SPF
        self.subject = subject
        self.list_unsubscribe = list_unsubscribe
        self.size_estimate = size_estimate
        self.history_id = history_id
        self.internal_date = internal_date
        # setting this to an empty list instead of parts made it stop adding to a "master" parts list recursively
        self.parts = []
        
    def add(self, part):
        self.parts.append(part)

# %%
class Part(Representer):
    def __init__(self, mime_type='', content_type='', content_transfer_encoding='', body_size='', body_data=''):
        self.mime_type = mime_type
        self.content_type = content_type
        self.content_transfer_encoding = content_transfer_encoding
        self.body_size = body_size
        self.body_data = body_data

# %%
"""Shows basic usage of the Gmail API.
Lists the user's Gmail labels.
"""
creds = None
# The file token.pickle stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
if os.path.exists('token.pickle'):
    with open('token.pickle', 'rb') as token:
        creds = pickle.load(token)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            '../credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.pickle', 'wb') as token:
        pickle.dump(creds, token)

service = build('gmail', 'v1', credentials=creds)

# %%
def get_message_list():
    results = service.users().messages().list(userId='me', q='').execute()
    return results

# %%
def get_message(msg_id):
    results = service.users().messages().get(userId='me', id=msg_id).execute()
    return results

# %%
messages = []

# %%
message_threads = get_message_list()['messages']
message_threads[0]
# Out:
# {'id': '17113ceb4d986aab', 'threadId': '17113ceb4d986aab'}

# %%
for i, message_thread in enumerate(message_threads):
    print(message_thread)
    message = get_message(message_thread['id'])
    message_id = message['id']
    thread_id = message['threadId']
    label_ids = message['labelIds']
    for header in message['payload']['headers']:
        if header['name'] == 'Date': date = header['value']
        if header['name'] == 'From': from_ = header['value']
        if header['name'] == 'Received': received = header['value']
        if header['name'] == 'Received-SPF': received_SPF = header['value']
        if header['name'] == 'Subject': subject = header['value']
        if header['name'] == 'List-Unsubscribe': list_unsubscribe = header['value']
    size_estimate = message['sizeEstimate']
    history_id = message['historyId']
    internal_date = message['internalDate']
    _message = Message(message_id, thread_id, label_ids, date, from_,\
             received, received_SPF, list_unsubscribe,\
             size_estimate, history_id, internal_date)
    # pprint(message['payload'])
    try:
        for ii, part in enumerate(message['payload']['parts']):
            print(i)
            print(ii)
            mime_type = part['mimeType']
            for header in part['headers']:
                if header['name'] == 'Content-Type': content_type = header['value']
                if header['name'] == 'Content-Transfer-Encoding': content_transfer_encoding = header['value']
            body_size = part['body']['size']
            # body_data = part['body']['data']
            body_data = ''
            _part = Part(mime_type, content_type, content_transfer_encoding, body_size, body_data)
            _message.add(_part)
            print(ii)
            _part = None
    except:
        print(message_id)
        _part = None
    messages.append(_message)
    _message = None
# Out:
# {'id': '17113be362a6f56f', 'threadId': '17113be362a6f56f'}
# 0
# 0
# 0
# 0
# 1
# 1
# {'id': '17112b1ce27fcb66', 'threadId': '17112b1ce27fcb66'}
# 1
# 0
# 0
# 1
# 1
# 1
# {'id': '171125a020c89b0a', 'threadId': '171125a020c89b0a'}
# 2
# 0
# 0
# 2
# 1
# 1
# {'id': '17111c80daba19e3', 'threadId': '17111c80daba19e3'}
# 3
# 0
# 0
# 3
# 1
# 1
# {'id': '17111340e74a3e9b', 'threadId': '17111340e74a3e9b'}
# 4
# 0
# 0
# 4
# 1
# 1
# {'id': '17110adeff87e35c', 'threadId': '17110adeff87e35c'}
# 5
# 0
# 0
# 5
# 1
# 1
# {'id': '171101e651aa226d', 'threadId': '171101e651aa226d'}
# 171101e651aa226d
# {'id': '1710f738c9b989c6', 'threadId': '1710f738c9b989c6'}
# 7
# 0
# 0
# 7
# 1
# 1
# {'id': '1710f37bea23792c', 'threadId': '1710f37bea23792c'}
# 1710f37bea23792c
# {'id': '1710f35d099f1ae1', 'threadId': '1710e8e0c39d7669'}
# 9
# 0
# 0
# 9
# 1
# 1
# {'id': '1710f16f868f42d0', 'threadId': '1710e8e0c39d7669'}
# 10
# 0
# 0
# 10
# 1
# 1
# {'id': '1710ef7c102feb08', 'threadId': '1710ef7c102feb08'}
# 11
# 0
# 0
# 11
# 1
# 1
# {'id': '1710eb871fc902a1', 'threadId': '1710eb871fc902a1'}
# 12
# 0
# 0
# 12
# 1
# 1
# {'id': '1710e9e2784872e1', 'threadId': '1710e9e2784872e1'}
# 13
# 0
# 0
# 13
# 1
# 1
# {'id': '1710e8e0c39d7669', 'threadId': '1710e8e0c39d7669'}
# 14
# 0
# 0
# 14
# 1
# 1
# {'id': '1710e78830f68edc', 'threadId': '1710e78830f68edc'}
# 15
# 0
# 0
# 15
# 1
# 1
# {'id': '1710e3ff8bae78bf', 'threadId': '1710e3ff8bae78bf'}
# 16
# 0
# 0
# 16
# 1
# 1
# {'id': '1710e3361e3e7719', 'threadId': '1710e333d5d9caa9'}
# 17
# 0
# 0
# 17
# 1
# 1
# {'id': '1710e3039cc09e09', 'threadId': '1710e3039cc09e09'}
# 18
# 0
# 0
# 18
# 1
# 1
# {'id': '1710ddef6b905652', 'threadId': '1710ddef6b905652'}
# 19
# 0
# 0
# 19
# 1
# 1
# 19
# 2
# 2
# {'id': '1710caaf028bf11f', 'threadId': '1710caaf028bf11f'}
# 20
# 0
# 0
# 20
# 1
# 1
# {'id': '1710ca149cefbc3e', 'threadId': '1710ca149cefbc3e'}
# 21
# 0
# 0
# 21
# 1
# 1
# {'id': '1710c0a717db161b', 'threadId': '1710c0a717db161b'}
# 22
# 0
# 0
# 22
# 1
# 1
# {'id': '1710b93c26812107', 'threadId': '1710b93c26812107'}
# 23
# 0
# 0
# 23
# 1
# 1
# {'id': '1710a81582596aba', 'threadId': '1710a81582596aba'}
# 24
# 0
# 0
# 24
# 1
# 1
# {'id': '1710a72371818dd5', 'threadId': '1710a72371818dd5'}
# 25
# 0
# 0
# 25
# 1
# 1
# {'id': '1710a580bdfa076e', 'threadId': '1710a03f179e6156'}
# 26
# 0
# 0
# 26
# 1
# 1
# {'id': '1710a28684d3268d', 'threadId': '1710a03f179e6156'}
# 27
# 0
# 0
# 27
# 1
# 1
# {'id': '1710a25520d8c749', 'threadId': '1710a03f179e6156'}
# 28
# 0
# 0
# 28
# 1
# 1
# {'id': '1710a03f179e6156', 'threadId': '1710a03f179e6156'}
# 29
# 0
# 0
# 29
# 1
# 1
# {'id': '17109e4decb71f2f', 'threadId': '17109e4decb71f2f'}
# 30
# 0
# 0
# 30
# 1
# 1
# {'id': '17109d975d786a40', 'threadId': '17109d975d786a40'}
# 31
# 0
# 0
# 31
# 1
# 1
# {'id': '171096d47778ce36', 'threadId': '171096d47778ce36'}
# 32
# 0
# 0
# 32
# 1
# 1
# {'id': '171095d405bd9749', 'threadId': '171095d405bd9749'}
# 33
# 0
# 0
# 33
# 1
# 1
# {'id': '1710948ecc61a70c', 'threadId': '1710948ecc61a70c'}
# 34
# 0
# 0
# 34
# 1
# 1
# {'id': '17108e1ba63bf261', 'threadId': '17108e1ba63bf261'}
# 35
# 0
# 0
# 35
# 1
# 1
# {'id': '17108a51fc9be488', 'threadId': '17108a51fc9be488'}
# 36
# 0
# 0
# 36
# 1
# 1
# {'id': '171089c798c277f6', 'threadId': '171089c798c277f6'}
# 171089c798c277f6
# {'id': '171082a3c0396d41', 'threadId': '171082a3c0396d41'}
# 38
# 0
# 0
# 38
# 1
# 1
# {'id': '1710761394c8073c', 'threadId': '1710761394c8073c'}
# 39
# 0
# 0
# 39
# 1
# 1
# {'id': '17106e30b527c11d', 'threadId': '17106e30b527c11d'}
# 40
# 0
# 0
# 40
# 1
# 1
# {'id': '17106db20d4eaa70', 'threadId': '17106db20d4eaa70'}
# 41
# 0
# 0
# 41
# 1
# 1
# {'id': '171065c800472c6c', 'threadId': '171065c800472c6c'}
# 42
# 0
# 0
# 42
# 1
# 1
# {'id': '1710532deebf3790', 'threadId': '1710532deebf3790'}
# 1710532deebf3790
# {'id': '171048d30b80f542', 'threadId': '171048d30b80f542'}
# 171048d30b80f542
# {'id': '17104489a1354632', 'threadId': '17104489a1354632'}
# 45
# 0
# 0
# 45
# 1
# 1
# {'id': '17104366b32d545a', 'threadId': '17104366b32d545a'}
# 46
# 0
# 0
# 46
# 1
# 1
# {'id': '171042dd9ee42de1', 'threadId': '171042dd9ee42de1'}
# 47
# 0
# 0
# 47
# 1
# 1
# {'id': '1710402f7c4883b7', 'threadId': '1710402f7c4883b7'}
# 48
# 0
# 0
# 48
# 1
# 1
# {'id': '17103b1586774a9c', 'threadId': '17103b1586774a9c'}
# 17103b1586774a9c
# {'id': '17103b070e0f3872', 'threadId': '17103a470f5a8076'}
# 50
# 0
# 0
# 50
# 1
# 1
# {'id': '17103afcc1925774', 'threadId': '17103afcc1925774'}
# 17103afcc1925774
# {'id': '17103a470f5a8076', 'threadId': '17103a470f5a8076'}
# 52
# 0
# 0
# 52
# 1
# 1
# {'id': '1710394a4cbd4f9a', 'threadId': '1710394a4cbd4f9a'}
# 53
# 0
# 0
# 53
# 1
# 1
# {'id': '1710393d23ba5a3b', 'threadId': '1710393d23ba5a3b'}
# 1710393d23ba5a3b
# {'id': '171038bbada38199', 'threadId': '171038bbada38199'}
# 55
# 0
# 0
# 55
# 1
# 1
# {'id': '17102d3d2dbe5ccb', 'threadId': '17102d3d2dbe5ccb'}
# 56
# 0
# 0
# 56
# 1
# 1
# {'id': '17102c37c2439dad', 'threadId': '17102c37c2439dad'}
# 57
# 0
# 0
# 57
# 1
# 1
# {'id': '1710204afc6c50a1', 'threadId': '1710204afc6c50a1'}
# 1710204afc6c50a1
# {'id': '17101c4cdf43a17c', 'threadId': '17101c4cdf43a17c'}
# 59
# 0
# 0
# 59
# 1
# 1
# {'id': '171006847c6e0e00', 'threadId': '171006847c6e0e00'}
# 60
# 0
# 0
# 60
# 1
# 1
# {'id': '171000eaf14bc118', 'threadId': '171000eaf14bc118'}
# 171000eaf14bc118
# {'id': '170ff58db2329045', 'threadId': '170ff58db2329045'}
# 62
# 0
# 0
# 62
# 1
# 1
# {'id': '170ff20c01647931', 'threadId': '170ff20c01647931'}
# 63
# 0
# 0
# 63
# 1
# 1
# {'id': '170ff09d8682ee73', 'threadId': '170ff09d8682ee73'}
# 64
# 0
# 0
# 64
# 1
# 1
# {'id': '170fe60536dbd8eb', 'threadId': '170fe60536dbd8eb'}
# 170fe60536dbd8eb
# {'id': '170fe27f22f37136', 'threadId': '170fe27f22f37136'}
# 170fe27f22f37136
# {'id': '170fdd8186a5baae', 'threadId': '170fdd8186a5baae'}
# 67
# 0
# 0
# 67
# 1
# 1
# {'id': '170fdd74940ecd22', 'threadId': '170fdd74940ecd22'}
# 68
# 0
# 0
# 68
# 1
# 1
# {'id': '170fdb94634b0ef8', 'threadId': '170fdb94634b0ef8'}
# 170fdb94634b0ef8
# {'id': '170fd99b758c5b0f', 'threadId': '170fd99b758c5b0f'}
# 70
# 0
# 0
# 70
# 1
# 1
# {'id': '170fd28d2c86289a', 'threadId': '170fd28d2c86289a'}
# 71
# 0
# 0
# 71
# 1
# 1
# {'id': '170fcd5320a33d1c', 'threadId': '170fcd5320a33d1c'}
# 170fcd5320a33d1c
# {'id': '170fc9b48193fdb2', 'threadId': '170fc9b48193fdb2'}
# 73
# 0
# 0
# 73
# 1
# 1
# {'id': '170fc133a2478673', 'threadId': '170fc133a2478673'}
# 74
# 0
# 0
# 74
# 1
# 1
# {'id': '170fb82cffe84f9b', 'threadId': '170fb82cffe84f9b'}
# 75
# 0
# 0
# 75
# 1
# 1
# {'id': '170fa9c6251a9fec', 'threadId': '170fa9c6251a9fec'}
# 76
# 0
# 0
# 76
# 1
# 1
# {'id': '170f9fef6f08645c', 'threadId': '170f9fef6f08645c'}
# 77
# 0
# 0
# 77
# 1
# 1
# {'id': '170f9fd29b4a7d43', 'threadId': '170f9fd29b4a7d43'}
# 78
# 0
# 0
# 78
# 1
# 1
# {'id': '170f9fb1676638c3', 'threadId': '170f9fb1676638c3'}
# 79
# 0
# 0
# 79
# 1
# 1
# {'id': '170f9accb8357bc4', 'threadId': '170f9accb8357bc4'}
# 80
# 0
# 0
# 80
# 1
# 1
# {'id': '170f9ac17b2ce936', 'threadId': '170f9ac17b2ce936'}
# 81
# 0
# 0
# 81
# 1
# 1
# {'id': '170f97a220ec749c', 'threadId': '170f97a220ec749c'}
# 170f97a220ec749c
# {'id': '170f96f1278beab6', 'threadId': '170f96f1278beab6'}
# 170f96f1278beab6
# {'id': '170f969659a8bb60', 'threadId': '170f969659a8bb60'}
# 170f969659a8bb60
# {'id': '170f8bb0c7f9301f', 'threadId': '170f8bb0c7f9301f'}
# 85
# 0
# 0
# 85
# 1
# 1
# {'id': '170f891aac5c1c29', 'threadId': '170f891aac5c1c29'}
# 170f891aac5c1c29
# {'id': '170f86ee64a5ab6b', 'threadId': '170f86ee64a5ab6b'}
# 87
# 0
# 0
# 87
# 1
# 1
# {'id': '170f80c352ca6447', 'threadId': '170f80c352ca6447'}
# 88
# 0
# 0
# 88
# 1
# 1
# {'id': '170f7af8048b0804', 'threadId': '170f7af8048b0804'}
# 170f7af8048b0804
# {'id': '170f776a3c789d1b', 'threadId': '170f776a3c789d1b'}
# 90
# 0
# 0
# 90
# 1
# 1
# {'id': '170f6f663dfe6c43', 'threadId': '170f6f663dfe6c43'}
# 91
# 0
# 0
# 91
# 1
# 1
# {'id': '170f65e989c747bf', 'threadId': '170f65e989c747bf'}
# 170f65e989c747bf
# {'id': '170f5c063e4bff55', 'threadId': '170f5c063e4bff55'}
# 170f5c063e4bff55
# {'id': '170f5a61326532c5', 'threadId': '170f5a61326532c5'}
# 170f5a61326532c5
# {'id': '170f578cb62e4410', 'threadId': '170f578cb62e4410'}
# 95
# 0
# 0
# 95
# 1
# 1
# {'id': '170f5260c7b763cb', 'threadId': '170f5260c7b763cb'}
# 96
# 0
# 0
# 96
# 1
# 1
# {'id': '170f4d84cb38b7a2', 'threadId': '170f4d84cb38b7a2'}
# 97
# 0
# 0
# 97
# 1
# 1
# {'id': '170f4d5b0ab03e36', 'threadId': '170f4d5b0ab03e36'}
# 98
# 0
# 0
# 98
# 1
# 1
# {'id': '170f4cd092a0b833', 'threadId': '170f4cd092a0b833'}
# 99
# 0
# 0
# 99
# 1
# 1

# %%
messages = []
for i, message_thread in enumerate(message_threads):
    message_data = {}
    print(message_thread)
    message = get_message(message_thread['id'])
    message_data['message_id'] = message['id']
    message_data['thread_id'] = message['threadId']
    message_data['label_ids'] = message['labelIds']
    for header in message['payload']['headers']:
        if header['name'].lower() == 'date': message_data['date'] = header['value']
        if header['name'].lower() == 'from': message_data['from_'] = header['value']
        if header['name'].lower() == 'received': message_data['received'] = header['value']
        if header['name'].lower() == 'received-spf': message_data['received_SPF'] = header['value']
        if header['name'].lower() == 'subject': message_data['subject'] = header['value']
        if header['name'].lower() == 'list-unsubscribe': message_data['list_unsubscribe'] = header['value']
    message_data['size_estimate'] = message['sizeEstimate']
    message_data['history_id'] = message['historyId']
    message_data['internal_date'] = message['internalDate']
    message_data['parts'] = []
    try:
        for ii, part in enumerate(message['payload']['parts']):
            part_data = {}
            part_data['mime_type'] = part['mimeType']
            for header in part['headers']:
                if header['name'].lower() == 'Content-Type': part_data['content_type'] = header['value']
                if header['name'].lower() == 'Content-Transfer-Encoding': part_data['content_transfer_encoding'] = header['value']
            part_data['body_size'] = part['body']['size']
            # part_data['body_data'] = part['body']['data']
            body_data = ''
            message_data['parts'].append(part_data)
    except:
        print(i, message_thread['id'])
    messages.append(message_data)
# Out:
# {'id': '17113ceb4d986aab', 'threadId': '17113ceb4d986aab'}
# {'id': '17113be362a6f56f', 'threadId': '17113be362a6f56f'}
# {'id': '17112b1ce27fcb66', 'threadId': '17112b1ce27fcb66'}
# {'id': '171125a020c89b0a', 'threadId': '171125a020c89b0a'}
# {'id': '17111c80daba19e3', 'threadId': '17111c80daba19e3'}
# {'id': '17111340e74a3e9b', 'threadId': '17111340e74a3e9b'}
# {'id': '17110adeff87e35c', 'threadId': '17110adeff87e35c'}
# {'id': '171101e651aa226d', 'threadId': '171101e651aa226d'}
# 7 171101e651aa226d
# {'id': '1710f738c9b989c6', 'threadId': '1710f738c9b989c6'}
# {'id': '1710f37bea23792c', 'threadId': '1710f37bea23792c'}
# 9 1710f37bea23792c
# {'id': '1710f35d099f1ae1', 'threadId': '1710e8e0c39d7669'}
# {'id': '1710f16f868f42d0', 'threadId': '1710e8e0c39d7669'}
# {'id': '1710ef7c102feb08', 'threadId': '1710ef7c102feb08'}
# {'id': '1710eb871fc902a1', 'threadId': '1710eb871fc902a1'}
# {'id': '1710e9e2784872e1', 'threadId': '1710e9e2784872e1'}
# {'id': '1710e8e0c39d7669', 'threadId': '1710e8e0c39d7669'}
# {'id': '1710e78830f68edc', 'threadId': '1710e78830f68edc'}
# {'id': '1710e3ff8bae78bf', 'threadId': '1710e3ff8bae78bf'}
# {'id': '1710e3361e3e7719', 'threadId': '1710e333d5d9caa9'}
# {'id': '1710e3039cc09e09', 'threadId': '1710e3039cc09e09'}
# {'id': '1710ddef6b905652', 'threadId': '1710ddef6b905652'}
# {'id': '1710caaf028bf11f', 'threadId': '1710caaf028bf11f'}
# {'id': '1710ca149cefbc3e', 'threadId': '1710ca149cefbc3e'}
# {'id': '1710c0a717db161b', 'threadId': '1710c0a717db161b'}
# {'id': '1710b93c26812107', 'threadId': '1710b93c26812107'}
# {'id': '1710a81582596aba', 'threadId': '1710a81582596aba'}
# {'id': '1710a72371818dd5', 'threadId': '1710a72371818dd5'}
# {'id': '1710a580bdfa076e', 'threadId': '1710a03f179e6156'}
# {'id': '1710a28684d3268d', 'threadId': '1710a03f179e6156'}
# {'id': '1710a25520d8c749', 'threadId': '1710a03f179e6156'}
# {'id': '1710a03f179e6156', 'threadId': '1710a03f179e6156'}
# {'id': '17109e4decb71f2f', 'threadId': '17109e4decb71f2f'}
# {'id': '17109d975d786a40', 'threadId': '17109d975d786a40'}
# {'id': '171096d47778ce36', 'threadId': '171096d47778ce36'}
# {'id': '171095d405bd9749', 'threadId': '171095d405bd9749'}
# {'id': '1710948ecc61a70c', 'threadId': '1710948ecc61a70c'}
# {'id': '17108e1ba63bf261', 'threadId': '17108e1ba63bf261'}
# {'id': '17108a51fc9be488', 'threadId': '17108a51fc9be488'}
# {'id': '171089c798c277f6', 'threadId': '171089c798c277f6'}
# 38 171089c798c277f6
# {'id': '171082a3c0396d41', 'threadId': '171082a3c0396d41'}
# {'id': '1710761394c8073c', 'threadId': '1710761394c8073c'}
# {'id': '17106e30b527c11d', 'threadId': '17106e30b527c11d'}
# {'id': '17106db20d4eaa70', 'threadId': '17106db20d4eaa70'}
# {'id': '171065c800472c6c', 'threadId': '171065c800472c6c'}
# {'id': '1710532deebf3790', 'threadId': '1710532deebf3790'}
# 44 1710532deebf3790
# {'id': '171048d30b80f542', 'threadId': '171048d30b80f542'}
# 45 171048d30b80f542
# {'id': '17104489a1354632', 'threadId': '17104489a1354632'}
# {'id': '17104366b32d545a', 'threadId': '17104366b32d545a'}
# {'id': '171042dd9ee42de1', 'threadId': '171042dd9ee42de1'}
# {'id': '1710402f7c4883b7', 'threadId': '1710402f7c4883b7'}
# {'id': '17103b1586774a9c', 'threadId': '17103b1586774a9c'}
# 50 17103b1586774a9c
# {'id': '17103b070e0f3872', 'threadId': '17103a470f5a8076'}
# {'id': '17103afcc1925774', 'threadId': '17103afcc1925774'}
# 52 17103afcc1925774
# {'id': '17103a470f5a8076', 'threadId': '17103a470f5a8076'}
# {'id': '1710394a4cbd4f9a', 'threadId': '1710394a4cbd4f9a'}
# {'id': '1710393d23ba5a3b', 'threadId': '1710393d23ba5a3b'}
# 55 1710393d23ba5a3b
# {'id': '171038bbada38199', 'threadId': '171038bbada38199'}
# {'id': '17102d3d2dbe5ccb', 'threadId': '17102d3d2dbe5ccb'}
# {'id': '17102c37c2439dad', 'threadId': '17102c37c2439dad'}
# {'id': '1710204afc6c50a1', 'threadId': '1710204afc6c50a1'}
# 59 1710204afc6c50a1
# {'id': '17101c4cdf43a17c', 'threadId': '17101c4cdf43a17c'}
# {'id': '171006847c6e0e00', 'threadId': '171006847c6e0e00'}
# {'id': '171000eaf14bc118', 'threadId': '171000eaf14bc118'}
# 62 171000eaf14bc118
# {'id': '170ff58db2329045', 'threadId': '170ff58db2329045'}
# {'id': '170ff20c01647931', 'threadId': '170ff20c01647931'}
# {'id': '170ff09d8682ee73', 'threadId': '170ff09d8682ee73'}
# {'id': '170fe60536dbd8eb', 'threadId': '170fe60536dbd8eb'}
# 66 170fe60536dbd8eb
# {'id': '170fe27f22f37136', 'threadId': '170fe27f22f37136'}
# 67 170fe27f22f37136
# {'id': '170fdd8186a5baae', 'threadId': '170fdd8186a5baae'}
# {'id': '170fdd74940ecd22', 'threadId': '170fdd74940ecd22'}
# {'id': '170fdb94634b0ef8', 'threadId': '170fdb94634b0ef8'}
# 70 170fdb94634b0ef8
# {'id': '170fd99b758c5b0f', 'threadId': '170fd99b758c5b0f'}
# {'id': '170fd28d2c86289a', 'threadId': '170fd28d2c86289a'}
# {'id': '170fcd5320a33d1c', 'threadId': '170fcd5320a33d1c'}
# 73 170fcd5320a33d1c
# {'id': '170fc9b48193fdb2', 'threadId': '170fc9b48193fdb2'}
# {'id': '170fc133a2478673', 'threadId': '170fc133a2478673'}
# {'id': '170fb82cffe84f9b', 'threadId': '170fb82cffe84f9b'}
# {'id': '170fa9c6251a9fec', 'threadId': '170fa9c6251a9fec'}
# {'id': '170f9fef6f08645c', 'threadId': '170f9fef6f08645c'}
# {'id': '170f9fd29b4a7d43', 'threadId': '170f9fd29b4a7d43'}
# {'id': '170f9fb1676638c3', 'threadId': '170f9fb1676638c3'}
# {'id': '170f9accb8357bc4', 'threadId': '170f9accb8357bc4'}
# {'id': '170f9ac17b2ce936', 'threadId': '170f9ac17b2ce936'}
# {'id': '170f97a220ec749c', 'threadId': '170f97a220ec749c'}
# 83 170f97a220ec749c
# {'id': '170f96f1278beab6', 'threadId': '170f96f1278beab6'}
# 84 170f96f1278beab6
# {'id': '170f969659a8bb60', 'threadId': '170f969659a8bb60'}
# 85 170f969659a8bb60
# {'id': '170f8bb0c7f9301f', 'threadId': '170f8bb0c7f9301f'}
# {'id': '170f891aac5c1c29', 'threadId': '170f891aac5c1c29'}
# 87 170f891aac5c1c29
# {'id': '170f86ee64a5ab6b', 'threadId': '170f86ee64a5ab6b'}
# {'id': '170f80c352ca6447', 'threadId': '170f80c352ca6447'}
# {'id': '170f7af8048b0804', 'threadId': '170f7af8048b0804'}
# 90 170f7af8048b0804
# {'id': '170f776a3c789d1b', 'threadId': '170f776a3c789d1b'}
# {'id': '170f6f663dfe6c43', 'threadId': '170f6f663dfe6c43'}
# {'id': '170f65e989c747bf', 'threadId': '170f65e989c747bf'}
# 93 170f65e989c747bf
# {'id': '170f5c063e4bff55', 'threadId': '170f5c063e4bff55'}
# 94 170f5c063e4bff55
# {'id': '170f5a61326532c5', 'threadId': '170f5a61326532c5'}
# 95 170f5a61326532c5
# {'id': '170f578cb62e4410', 'threadId': '170f578cb62e4410'}
# {'id': '170f5260c7b763cb', 'threadId': '170f5260c7b763cb'}
# {'id': '170f4d84cb38b7a2', 'threadId': '170f4d84cb38b7a2'}
# {'id': '170f4d5b0ab03e36', 'threadId': '170f4d5b0ab03e36'}

# %%
for m in messages:
    pprint(vars(m))
# Out:
# {'date': 'Wed, 25 Mar 2020 17:16:14 +0000',
#  'from_': 'Twitter <info@twitter.com>',
#  'history_id': '1585156574000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_SOCIAL', 'INBOX'],
#  'list_unsubscribe': 100980,
#  'message_id': '17112b1ce27fcb66',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4188, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 84518, 'body_data': ''}],
#  'received': 'from spruce-goose-ah.twitter.com (spruce-goose-ah.twitter.com. '
#              '[199.59.150.77])        by mx.google.com with ESMTPS id '
#              'x12si16129823pgi.105.2020.03.25.10.16.14        for '
#              '<shortpoet@gmail.com>        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Wed, 25 '
#              'Mar 2020 10:16:15 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'n03460b90bd-e8b1b18795dd4786-shortpoet===gmail.com@bounce.twitter.com '
#                  'designates 199.59.150.77 as permitted sender) '
#                  'client-ip=199.59.150.77;',
#  'size_estimate': '5695266',
#  'subject': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=fa8f10c87ca6fd093fbd6710d052ab9d02de291d&iid=e8b1b18795dd4786acf50e5c35453e12&uid=762420025&nid=244+26&usbid=9>',
#  'thread_id': '17112b1ce27fcb66'}
# {'date': 'Wed, 25 Mar 2020 08:00:00 -0700',
#  'from_': 'The Clymb <events@theclymb.com>',
#  'history_id': '1585148400000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'INBOX'],
#  'list_unsubscribe': 39142,
#  'message_id': '171125a020c89b0a',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=utf-8', 'content_transfer_encoding': '8bit', 'body_size': 1050, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=utf-8', 'content_transfer_encoding': '8bit', 'body_size': 33995, 'body_data': ''}],
#  'received': 'by mta-em8.theclymb.com id hfdtlu2dh1ke for '
#              '<shortpoet@gmail.com>; Wed, 25 Mar 2020 07:43:49 -0700 '
#              '(envelope-from <events@theclymb.com>)',
#  'received_SPF': 'pass (google.com: domain of events@theclymb.com designates '
#                  '74.82.137.57 as permitted sender) client-ip=74.82.137.57;',
#  'size_estimate': '5695195',
#  'subject': '<mailto:list-unsubscribe@theclymb.com?subject=unsubscribe>',
#  'thread_id': '171125a020c89b0a'}
# {'date': 'Wed, 25 Mar 2020 13:00:00 +0000 (UTC)',
#  'from_': 'Medium Daily Digest <noreply@medium.com>',
#  'history_id': '1585141200000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#  'list_unsubscribe': 130679,
#  'message_id': '17111c80daba19e3',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 17282, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 99866, 'body_data': ''}],
#  'received': 'from MTgyMzE0NA (unknown) by ismtpd0033p1mdw1.sendgrid.net (SG) '
#              'with HTTP id 94jifWo1Tnqr_cd9wLxDmg Wed, 25 Mar 2020 '
#              '08:12:31.703 +0000 (UTC)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'bounces+1823144-4c20-shortpoet=gmail.com@email.medium.com '
#                  'designates 167.89.47.62 as permitted sender) '
#                  'client-ip=167.89.47.62;',
#  'size_estimate': '5695110',
#  'subject': '<mailto:list-unsubscribe@theclymb.com?subject=unsubscribe>',
#  'thread_id': '17111c80daba19e3'}
# {'date': 'Wed, 25 Mar 2020 06:00:00 -0400',
#  'from_': 'Eastern Mountain Sports <easternmountainsports@em.ems.com>',
#  'history_id': '1585130400000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 36939,
#  'message_id': '17111340e74a3e9b',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 875, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 28120, 'body_data': ''}],
#  'received': 'from localhost (10.0.2.97) by ms157-045.bronto.com id '
#              'hfco282lr20e for <shortpoet@gmail.com>; Wed, 25 Mar 2020 '
#              '06:06:07 -0400 (envelope-from '
#              '<bkg5c8d147yy4aj7jqmb6tlduh1o1uyf-b@em.ems.com>)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'bkg5c8d147yy4aj7jqmb6tlduh1o1uyf-b@em.ems.com designates '
#                  '69.166.157.45 as permitted sender) client-ip=69.166.157.45;',
#  'size_estimate': '5694884',
#  'subject': '<mailto:bkg5c8d147yy4aj7jqmb6tlduh1o1uyf-u@em.ems.com>, '
#             '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/aqbmeqgiqcndapefhrcvjypuuucsbhn?td=bxc51SEykYFM-O9ll2pktAVnC4pS3utG4W_crDja2BzZ7tMv5_RHjTStpDpmlwi5-thnbR42fk2Fnh2ikx-Q6h1UcRBXbp7wRphbvNSsXGZdi8HyuI3_SBqeD4gPdAHoy9sLH4-lI11KgIQSBlU_0H-iXTiKIRbqZq&tid=36032205374529978492965224813135248444487986541616422078465637885513106377123585>',
#  'thread_id': '17111340e74a3e9b'}
# {'date': '25 Mar 2020 07:36:49 +0000',
#  'from_': '"Newegg.com" <Promo@promo.newegg.com>',
#  'history_id': '1585121809000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 34238,
#  'message_id': '17110adeff87e35c',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4382, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 22367, 'body_data': ''}],
#  'received': 'from nampmer22 (10.24.72.82) by p1-002126.promo.newegg.com id '
#              'hfc6ss2bq58a for <shortpoet@gmail.com>; Wed, 25 Mar 2020 '
#              '03:36:49 -0400 (envelope-from <Promo@promo.newegg.com>)',
#  'received_SPF': 'pass (google.com: domain of promo@promo.newegg.com '
#                  'designates 173.213.2.126 as permitted sender) '
#                  'client-ip=173.213.2.126;',
#  'size_estimate': '5694811',
#  'subject': '<mailto:unsubscribe-d9dd0021f276fca3fafbbfa410531ee5@promo.newegg.com?subject=Unsubscribe>',
#  'thread_id': '17110adeff87e35c'}
# {'date': 'Wed, 25 Mar 2020 05:15:59 +0000',
#  'from_': 'X-Mirage <x-mirage@x-mirage.com>',
#  'history_id': '1585113359000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 18845,
#  'message_id': '171101e651aa226d',
#  'parts': [],
#  'received': 'from a11-62.smtp-out.amazonses.com '
#              '(a11-62.smtp-out.amazonses.com. [54.240.11.62])        by '
#              'mx.google.com with ESMTPS id '
#              'o5si7468431qkb.11.2020.03.24.22.15.59        for '
#              '<shortpoet@gmail.com>        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-SHA bits=128/128);        Tue, 24 Mar '
#              '2020 22:15:59 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  '01000171101e63e0-cac16fa5-84d5-40f1-a6d0-995a62164b27-000000@amazonses.com '
#                  'designates 54.240.11.62 as permitted sender) '
#                  'client-ip=54.240.11.62;',
#  'size_estimate': '5694694',
#  'subject': '<http://news.x-mirage.com/unsubscribe/c9glAJSAXYE2ABSvtWPPVUsF9oS2EQsagveHaHYhWmU/NOhdveOr892DZS1GAE2n7q0g/RJjmqNrTpfADmlxbCHkxNQ>',
#  'thread_id': '171101e651aa226d'}
# {'date': 'Wed, 25 Mar 2020 02:09:22 +0000',
#  'from_': 'Twitter <info@twitter.com>',
#  'history_id': '1585102162000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_SOCIAL', 'INBOX'],
#  'list_unsubscribe': 100867,
#  'message_id': '1710f738c9b989c6',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4126, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 84523, 'body_data': ''}],
#  'received': 'from spruce-goose-al.twitter.com (spruce-goose-al.twitter.com. '
#              '[199.59.150.81])        by mx.google.com with ESMTPS id '
#              'd12si15038027pgt.114.2020.03.24.19.09.22        for '
#              '<shortpoet@gmail.com>        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Tue, 24 '
#              'Mar 2020 19:09:23 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'n0346c4c4e7-ffd1f27f26734468-shortpoet===gmail.com@bounce.twitter.com '
#                  'designates 199.59.150.81 as permitted sender) '
#                  'client-ip=199.59.150.81;',
#  'size_estimate': '5694623',
#  'subject': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=6d72196c554b55c986a0529e0007848634b367da&iid=ffd1f27f26734468bb93706e9336621c&uid=762420025&nid=244+26&usbid=9>',
#  'thread_id': '1710f738c9b989c6'}
# {'date': 'Wed, 25 Mar 2020 01:04:02 +0000',
#  'from_': 'Reddit <noreply@redditmail.com>',
#  'history_id': '1585098242000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#  'list_unsubscribe': 108084,
#  'message_id': '1710f37bea23792c',
#  'parts': [],
#  'received': 'from a30-210.smtp-out.amazonses.com '
#              '(a30-210.smtp-out.amazonses.com. [54.240.30.210])        by '
#              'mx.google.com with ESMTPS id '
#              'o15si11389645qtk.236.2020.03.24.18.04.03        for '
#              '<shortpoet@gmail.com>        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-SHA bits=128/128);        Tue, 24 Mar '
#              '2020 18:04:03 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  '010001710f37bb5f-aeb1ee86-29ba-404d-b9d6-282f8de24277-000000@amazonses.com '
#                  'designates 54.240.30.210 as permitted sender) '
#                  'client-ip=54.240.30.210;',
#  'size_estimate': '5695109',
#  'subject': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=6d72196c554b55c986a0529e0007848634b367da&iid=ffd1f27f26734468bb93706e9336621c&uid=762420025&nid=244+26&usbid=9>',
#  'thread_id': '1710f37bea23792c'}
# {'date': 'Wed, 25 Mar 2020 01:01:55 +0000 (GMT)',
#  'from_': 'Google <no-reply@accounts.google.com>',
#  'history_id': '1585098115000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#  'list_unsubscribe': 11030,
#  'message_id': '1710f35d099f1ae1',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="UTF-8"; format=flowed; delsp=yes', 'content_transfer_encoding': 'base64', 'body_size': 573, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="UTF-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4575, 'body_data': ''}],
#  'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#              '[209.85.220.73])        by mx.google.com with SMTPS id '
#              'm66sor14659780qkd.149.2020.03.24.18.01.57        for '
#              '<shortpoet@gmail.com>        (Google Transport Security);        '
#              'Tue, 24 Mar 2020 18:01:57 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  '3hk16xggtccmwx-0nyu7jllx3w21.pxxpun.lxv1qx02yxn2pvjru.lxv@gaia.bounces.google.com '
#                  'designates 209.85.220.73 as permitted sender) '
#                  'client-ip=209.85.220.73;',
#  'size_estimate': '5695108',
#  'subject': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=6d72196c554b55c986a0529e0007848634b367da&iid=ffd1f27f26734468bb93706e9336621c&uid=762420025&nid=244+26&usbid=9>',
#  'thread_id': '1710e8e0c39d7669'}
# {'date': 'Wed, 25 Mar 2020 00:28:14 +0000 (GMT)',
#  'from_': 'Google <no-reply@accounts.google.com>',
#  'history_id': '1585096094000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#  'list_unsubscribe': 11033,
#  'message_id': '1710f16f868f42d0',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="UTF-8"; format=flowed; delsp=yes', 'content_transfer_encoding': 'base64', 'body_size': 576, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="UTF-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4577, 'body_data': ''}],
#  'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#              '[209.85.220.73])        by mx.google.com with SMTPS id '
#              'dl5sor5751163qvb.4.2020.03.24.17.28.16        for '
#              '<shortpoet@gmail.com>        (Google Transport Security);        '
#              'Tue, 24 Mar 2020 17:28:16 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  '3n6v6xggtcc478-by95iuww8e7dc.08805y.w86c18bd98yd06u25.w86@gaia.bounces.google.com '
#                  'designates 209.85.220.73 as permitted sender) '
#                  'client-ip=209.85.220.73;',
#  'size_estimate': '5695108',
#  'subject': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=6d72196c554b55c986a0529e0007848634b367da&iid=ffd1f27f26734468bb93706e9336621c&uid=762420025&nid=244+26&usbid=9>',
#  'thread_id': '1710e8e0c39d7669'}
# {'date': 'Tue, 24 Mar 2020 23:54:02 +0000',
#  'from_': 'PayPal <paypal@mail.paypal.com>',
#  'history_id': '1585094042000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 73838,
#  'message_id': '1710ef7c102feb08',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 1898, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 62333, 'body_data': ''}],
#  'received': 'from [10.233.84.191] ([10.233.84.191:41060]) by pc1udsmtn1n12 '
#              '(envelope-from <bounce@mail.paypal.com>) (ecelerity 3.6.9.48312 '
#              'r(Core:3.6.9.0)) with ECSTREAM id 41/E2-37514-A9D9A7E5; Tue, 24 '
#              'Mar 2020 23:54:02 +0000',
#  'received_SPF': 'pass (google.com: domain of bounce@mail.paypal.com '
#                  'designates 142.54.244.111 as permitted sender) '
#                  'client-ip=142.54.244.111;',
#  'size_estimate': '5694384',
#  'subject': '<mailto:bounce-HP2v4000001710ef7a3da91f1b26e96639818073@mail.paypal.com?subject=list-unsubscribe>',
#  'thread_id': '1710ef7c102feb08'}
# {'date': '24 Mar 2020 22:39:40 +0000',
#  'from_': '"Newegg.com" <Promo@promo.newegg.com>',
#  'history_id': '1585089580000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 52471,
#  'message_id': '1710eb871fc902a1',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 3672, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 39154, 'body_data': ''}],
#  'received': 'from nampmer28 (10.24.72.88) by p1-002129.promo.newegg.com id '
#              'hfa6mo2bq582 for <shortpoet@gmail.com>; Tue, 24 Mar 2020 '
#              '18:39:40 -0400 (envelope-from <Promo@promo.newegg.com>)',
#  'received_SPF': 'pass (google.com: domain of promo@promo.newegg.com '
#                  'designates 173.213.2.129 as permitted sender) '
#                  'client-ip=173.213.2.129;',
#  'size_estimate': '5694316',
#  'subject': '<mailto:unsubscribe-0f032f8924d29f568835b85c05bfe6e0@promo.newegg.com?subject=Unsubscribe>',
#  'thread_id': '1710eb871fc902a1'}
# {'date': 'Tue, 24 Mar 2020 18:00:00 -0400',
#  'from_': 'Eastern Mountain Sports <easternmountainsports@em.ems.com>',
#  'history_id': '1585087200000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 41909,
#  'message_id': '1710e9e2784872e1',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 875, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 32874, 'body_data': ''}],
#  'received': 'from localhost (10.0.2.94) by ms157-045.bronto.com id '
#              'hfa3b22lr20g for <shortpoet@gmail.com>; Tue, 24 Mar 2020 '
#              '18:02:54 -0400 (envelope-from '
#              '<koynis6s924cip7ikqjl099locgdauyf-b@em.ems.com>)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'koynis6s924cip7ikqjl099locgdauyf-b@em.ems.com designates '
#                  '69.166.157.45 as permitted sender) client-ip=69.166.157.45;',
#  'size_estimate': '5694244',
#  'subject': '<mailto:koynis6s924cip7ikqjl099locgdauyf-u@em.ems.com>, '
#             '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/anlkekrvpsrfelotymarppyqmnqobah?td=WmNxo64PjUoLVfHZxupd5QDqlZS0DDv4bXXBKQGUafGk1b5XJZKbGRIKvWXj2lLUcGp7F-E0OU3LCbQb9EHd6u6bB7L1ibKN2gwWrd1YPFLXK1Db1m6jcZPgL2T9AiMof2V4nFlbSg6_j8qXjOBpyuw6qlrPyXL2uy&tid=00467544404529978492965224817246452550299816450523387446410344307483509656907010>',
#  'thread_id': '1710e9e2784872e1'}
# {'date': 'Tue, 24 Mar 2020 21:58:41 +0000 (GMT)',
#  'from_': 'Google <no-reply@accounts.google.com>',
#  'history_id': '1585087121000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#  'list_unsubscribe': 11033,
#  'message_id': '1710e8e0c39d7669',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="UTF-8"; format=flowed; delsp=yes', 'content_transfer_encoding': 'base64', 'body_size': 572, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="UTF-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4573, 'body_data': ''}],
#  'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#              '[209.85.220.73])        by mx.google.com with SMTPS id '
#              'z11sor11304793ioz.41.2020.03.24.14.58.41        for '
#              '<shortpoet@gmail.com>        (Google Transport Security);        '
#              'Tue, 24 Mar 2020 14:58:42 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  '3kyj6xggtcxolm-pcnjwyaamslrq.emmejc.amkqfmprnmcrekygj.amk@gaia.bounces.google.com '
#                  'designates 209.85.220.73 as permitted sender) '
#                  'client-ip=209.85.220.73;',
#  'size_estimate': '5694234',
#  'subject': '<mailto:koynis6s924cip7ikqjl099locgdauyf-u@em.ems.com>, '
#             '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/anlkekrvpsrfelotymarppyqmnqobah?td=WmNxo64PjUoLVfHZxupd5QDqlZS0DDv4bXXBKQGUafGk1b5XJZKbGRIKvWXj2lLUcGp7F-E0OU3LCbQb9EHd6u6bB7L1ibKN2gwWrd1YPFLXK1Db1m6jcZPgL2T9AiMof2V4nFlbSg6_j8qXjOBpyuw6qlrPyXL2uy&tid=00467544404529978492965224817246452550299816450523387446410344307483509656907010>',
#  'thread_id': '1710e8e0c39d7669'}
# {'date': 'Tue, 24 Mar 2020 14:00:00 -0700',
#  'from_': 'The Clymb <events@theclymb.com>',
#  'history_id': '1585083600000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 39085,
#  'message_id': '1710e78830f68edc',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=utf-8', 'content_transfer_encoding': '8bit', 'body_size': 1051, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=utf-8', 'content_transfer_encoding': '8bit', 'body_size': 34015, 'body_data': ''}],
#  'received': 'by mta-em11.theclymb.com id hf9ugo2dh1ka for '
#              '<shortpoet@gmail.com>; Tue, 24 Mar 2020 13:36:47 -0700 '
#              '(envelope-from <events@theclymb.com>)',
#  'received_SPF': 'pass (google.com: domain of events@theclymb.com designates '
#                  '74.82.137.60 as permitted sender) client-ip=74.82.137.60;',
#  'size_estimate': '5695119',
#  'subject': '<mailto:list-unsubscribe@theclymb.com?subject=unsubscribe>',
#  'thread_id': '1710e78830f68edc'}
# {'date': 'Tue, 24 Mar 2020 20:33:25 +0000',
#  'from_': 'Embassy Suites Niagara Falls Fallsview <noreply@touchbasemail.net>',
#  'history_id': '1585082005000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 13809,
#  'message_id': '1710e3ff8bae78bf',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 273, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 7885, 'body_data': ''}],
#  'received': 'from notl1-mailer-758c0f21.touchbasemail.net '
#              '(notl1-mailer-758c0f21.touchbasemail.net. '
#              '[2606:5480:1050:3:f833:e9ff:fe68:c0c8])        by mx.google.com '
#              'with ESMTPS id d3si3571505qkk.176.2020.03.24.13.33.25        for '
#              '<shortpoet@gmail.com>        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Tue, 24 '
#              'Mar 2020 13:33:25 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'bounces+6eedf8a4-d2dc-4d6a-bece-8b6163e20a63.dff0c2cc-6c6d-431e-ace4-8398dceed3fa@touchbasemail.net '
#                  'designates 2606:5480:1050:3:f833:e9ff:fe68:c0c8 as permitted '
#                  'sender) client-ip=2606:5480:1050:3:f833:e9ff:fe68:c0c8;',
#  'size_estimate': '5694066',
#  'subject': 'https://clients.touchbasemail.net/subscriptions/unsubscribe/6eedf8a4-d2dc-4d6a-bece-8b6163e20a63/dff0c2cc-6c6d-431e-ace4-8398dceed3fa',
#  'thread_id': '1710e3ff8bae78bf'}
# {'date': 'Tue, 24 Mar 2020 15:19:40 -0500',
#  'from_': 'Carlos Soriano <shortpoet@gmail.com>',
#  'history_id': '1585081180000',
#  'internal_date': '',
#  'label_ids': ['SENT'],
#  'list_unsubscribe': 802,
#  'message_id': '1710e3361e3e7719',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="UTF-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 79, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="UTF-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 211, 'body_data': ''}],
#  'received': 'from notl1-mailer-758c0f21.touchbasemail.net '
#              '(notl1-mailer-758c0f21.touchbasemail.net. '
#              '[2606:5480:1050:3:f833:e9ff:fe68:c0c8])        by mx.google.com '
#              'with ESMTPS id d3si3571505qkk.176.2020.03.24.13.33.25        for '
#              '<shortpoet@gmail.com>        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Tue, 24 '
#              'Mar 2020 13:33:25 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'bounces+6eedf8a4-d2dc-4d6a-bece-8b6163e20a63.dff0c2cc-6c6d-431e-ace4-8398dceed3fa@touchbasemail.net '
#                  'designates 2606:5480:1050:3:f833:e9ff:fe68:c0c8 as permitted '
#                  'sender) client-ip=2606:5480:1050:3:f833:e9ff:fe68:c0c8;',
#  'size_estimate': '5695042',
#  'subject': 'https://clients.touchbasemail.net/subscriptions/unsubscribe/6eedf8a4-d2dc-4d6a-bece-8b6163e20a63/dff0c2cc-6c6d-431e-ace4-8398dceed3fa',
#  'thread_id': '1710e333d5d9caa9'}
# {'date': 'Tue, 24 Mar 2020 15:16:06 -0500 (CDT)',
#  'from_': '"DevRel @ Okta" <devcommunity@reply.okta.com>',
#  'history_id': '1585080966000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#  'list_unsubscribe': 76041,
#  'message_id': '1710e3039cc09e09',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 5349, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 59507, 'body_data': ''}],
#  'received': 'from [10.1.87.249] ([10.1.87.249:51680] '
#              'helo=abmas03.marketo.org) by abmta15.marketo.org (envelope-from '
#              '<devcommunity@reply.okta.com>) (ecelerity 4.2.38.62370 r(:)) '
#              'with ESMTP id F0/AA-04013-68A6A7E5; Tue, 24 Mar 2020 15:16:06 '
#              '-0500',
#  'received_SPF': 'pass (google.com: domain of '
#                  '380-nlu-416.0.442611.0.0.58721.9.18172360@find.okta.com '
#                  'designates 192.28.150.151 as permitted sender) '
#                  'client-ip=192.28.150.151;',
#  'size_estimate': '5693981',
#  'subject': '<mailto:JFAXEV3LLFDGU6RVKAYEUVD2PB2DQ4RVJZ2WGVTMKQ3UMY2ZIRCDQVTQNA3HU5CSJE2DAPI.442611.58721.9@unsub-ab.mktomail.com>',
#  'thread_id': '1710e3039cc09e09'}
# {'date': 'Tue, 24 Mar 2020 13:47:25 -0500',
#  'from_': 'Carlos Soriano <soriano.carlos@gmail.com>',
#  'history_id': '1585075645000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#  'list_unsubscribe': 504873,
#  'message_id': '1710ddef6b905652',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=us-ascii', 'content_transfer_encoding': '7bit', 'body_size': 4, 'body_data': ''},
#            {'mime_type': 'image/jpeg', 'content_type': 'image/jpeg; name=Image-1.jpg; x-apple-part-url=82291A16-A982-46A2-829D-485EA739028C', 'content_transfer_encoding': 'base64', 'body_size': 364804, 'body_data': ''},
#            {'mime_type': 'text/plain', 'content_type': 'text/plain; charset=us-ascii', 'content_transfer_encoding': '7bit', 'body_size': 23, 'body_data': ''}],
#  'received': 'from ?IPv6:2600:6c40:200:3539:3071:f518:9b83:8783? '
#              '([2600:6c40:200:3539:3071:f518:9b83:8783])        by '
#              'smtp.gmail.com with ESMTPSA id '
#              'a136sm1479401qkb.15.2020.03.24.11.47.26        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Tue, 24 '
#              'Mar 2020 11:47:26 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of soriano.carlos@gmail.com '
#                  'designates 209.85.220.41 as permitted sender) '
#                  'client-ip=209.85.220.41;',
#  'size_estimate': '5693913',
#  'subject': '<mailto:JFAXEV3LLFDGU6RVKAYEUVD2PB2DQ4RVJZ2WGVTMKQ3UMY2ZIRCDQVTQNA3HU5CSJE2DAPI.442611.58721.9@unsub-ab.mktomail.com>',
#  'thread_id': '1710ddef6b905652'}
# {'date': 'Tue, 24 Mar 2020 06:10:41 -0700',
#  'from_': '"iZotope, Inc." <izotope@news.izotope.com>',
#  'history_id': '1585055441000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'Label_15'],
#  'list_unsubscribe': 41706,
#  'message_id': '1710caaf028bf11f',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="utf-8"', 'content_transfer_encoding': '8bit', 'body_size': 2510, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="utf-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 32748, 'body_data': ''}],
#  'received': 'from [35.166.8.133] ([35.166.8.133:23013] '
#              'helo=r44.news.izotope.com) by momentum02.or1.cpt.adobe.net '
#              '(envelope-from <bounce@news.izotope.com>) (ecelerity '
#              '4.2.31.59853 r(Core:4.2.31.1)) with ESMTP id '
#              'AD/E2-00617-B760A7E5; Tue, 24 Mar 2020 06:09:15 -0700',
#  'received_SPF': 'pass (google.com: domain of bounce@news.izotope.com '
#                  'designates 192.243.229.43 as permitted sender) '
#                  'client-ip=192.243.229.43;',
#  'size_estimate': '5693679',
#  'subject': '<mailto:JFAXEV3LLFDGU6RVKAYEUVD2PB2DQ4RVJZ2WGVTMKQ3UMY2ZIRCDQVTQNA3HU5CSJE2DAPI.442611.58721.9@unsub-ab.mktomail.com>',
#  'thread_id': '1710caaf028bf11f'}
# {'date': 'Tue, 24 Mar 2020 13:00:00 +0000 (UTC)',
#  'from_': 'Medium Daily Digest <noreply@medium.com>',
#  'history_id': '1585054800000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#  'list_unsubscribe': 131011,
#  'message_id': '1710ca149cefbc3e',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 17766, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 99619, 'body_data': ''}],
#  'received': 'from MTgyMzE0NA (unknown) by ismtpd0013p1iad2.sendgrid.net (SG) '
#              'with HTTP id 5Gg1SIucQuSC4vATHv6MQQ Tue, 24 Mar 2020 '
#              '10:12:22.715 +0000 (UTC)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'bounces+1823144-4c20-shortpoet=gmail.com@email.medium.com '
#                  'designates 149.72.133.6 as permitted sender) '
#                  'client-ip=149.72.133.6;',
#  'size_estimate': '5693912',
#  'subject': '<mailto:JFAXEV3LLFDGU6RVKAYEUVD2PB2DQ4RVJZ2WGVTMKQ3UMY2ZIRCDQVTQNA3HU5CSJE2DAPI.442611.58721.9@unsub-ab.mktomail.com>',
#  'thread_id': '1710ca149cefbc3e'}
# {'date': 'Tue, 24 Mar 2020 06:00:00 -0400',
#  'from_': 'Eastern Mountain Sports <easternmountainsports@em.ems.com>',
#  'history_id': '1585044000000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 38540,
#  'message_id': '1710c0a717db161b',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 875, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 29614, 'body_data': ''}],
#  'received': 'from localhost (10.0.2.130) by ms157-045.bronto.com id '
#              'hf7esu2lr20r for <shortpoet@gmail.com>; Tue, 24 Mar 2020 '
#              '06:04:55 -0400 (envelope-from '
#              '<9k6mrgn81bgxtzxta2vk4sukktu91uyf-b@em.ems.com>)',
#  'received_SPF': 'pass (google.com: domain of '
#                  '9k6mrgn81bgxtzxta2vk4sukktu91uyf-b@em.ems.com designates '
#                  '69.166.157.45 as permitted sender) client-ip=69.166.157.45;',
#  'size_estimate': '5693527',
#  'subject': '<mailto:9k6mrgn81bgxtzxta2vk4sukktu91uyf-u@em.ems.com>, '
#             '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/bzhgccuctjkcrmwhnkqfktnjwywzbch?td=Jk8__UgZ3y6qt3Htyr1e5AYnTTF6vsxKW4vjgS0r46WFfCG8gjQY3cY5xU1stHU6i43axsRyT8dpB30v_OrT1L-pNZvRNiJgbPjFG1hcGwYA62mQXo4IchMkJLP8NVcxE3REUesH31WAQpnyr6jWqXIv9y5WSOSyNM&tid=28384182514529978492965224816498163711986394156403100874919027654897519634410754>',
#  'thread_id': '1710c0a717db161b'}
# {'date': '24 Mar 2020 07:43:24 +0000',
#  'from_': '"Newegg.com" <Promo@promo.newegg.com>',
#  'history_id': '1585035804000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 39398,
#  'message_id': '1710b93c26812107',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4548, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 26816, 'body_data': ''}],
#  'received': 'from nampmer24 (10.24.72.84) by p1-002128.promo.newegg.com id '
#              'hf6vmq2bq58l for <shortpoet@gmail.com>; Tue, 24 Mar 2020 '
#              '03:43:24 -0400 (envelope-from <Promo@promo.newegg.com>)',
#  'received_SPF': 'pass (google.com: domain of promo@promo.newegg.com '
#                  'designates 173.213.2.128 as permitted sender) '
#                  'client-ip=173.213.2.128;',
#  'size_estimate': '5693456',
#  'subject': '<mailto:unsubscribe-c6a99c572036e3bad51d8b4aa43f3e1b@promo.newegg.com?subject=Unsubscribe>',
#  'thread_id': '1710b93c26812107'}
# {'date': 'Tue, 24 Mar 2020 03:06:21 +0000',
#  'from_': '"Brasil Brasil Cultural Center & Capoeira Batuque" '
#           '<capoeirabatuque.bbcc@gmail.com>',
#  'history_id': '1585019181000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 21037,
#  'message_id': '1710a81582596aba',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="us-ascii"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 800, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="utf-8"; format="fixed"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 11598, 'body_data': ''}],
#  'received': 'from 127.0.0.1 (localhost [127.0.0.1]) by mail11.mcsignup.com '
#              '(Mailchimp) with ESMTP id 48mbk523GZz35jnyc for '
#              '<shortpoet@gmail.com>; Tue, 24 Mar 2020 03:06:21 +0000 (GMT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'bounce-mcsys.us2_2835378.b4a9752948-shortpoet=gmail.com@mail11.mcsignup.com '
#                  'designates 198.2.140.131 as permitted sender) '
#                  'client-ip=198.2.140.131;',
#  'size_estimate': '5693341',
#  'subject': '<mailto:unsubscribe-c6a99c572036e3bad51d8b4aa43f3e1b@promo.newegg.com?subject=Unsubscribe>',
#  'thread_id': '1710a81582596aba'}
# {'date': 'Tue, 24 Mar 2020 02:49:48 +0000',
#  'from_': 'Twitter <info@twitter.com>',
#  'history_id': '1585018188000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_SOCIAL', 'INBOX'],
#  'list_unsubscribe': 97569,
#  'message_id': '1710a72371818dd5',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4257, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 81373, 'body_data': ''}],
#  'received': 'from spruce-goose-bc.twitter.com (spruce-goose-bc.twitter.com. '
#              '[199.59.150.98])        by mx.google.com with ESMTPS id '
#              'u11si12542038pfl.94.2020.03.23.19.49.49        for '
#              '<shortpoet@gmail.com>        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Mon, 23 '
#              'Mar 2020 19:49:49 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'n03453c0cbc-e315196d8edb4c67-shortpoet===gmail.com@bounce.twitter.com '
#                  'designates 199.59.150.98 as permitted sender) '
#                  'client-ip=199.59.150.98;',
#  'size_estimate': '5693027',
#  'subject': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=da23e45287f58e99677dd1beda545b1cc2b9f83e&iid=e315196d8edb4c6799ac813ed275cc17&uid=762420025&nid=244+26&usbid=9>',
#  'thread_id': '1710a72371818dd5'}
# {'date': 'Tue, 24 Mar 2020 02:21:13 +0000 (GMT)',
#  'from_': 'Google <no-reply@accounts.google.com>',
#  'history_id': '1585016473000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#  'list_unsubscribe': 11051,
#  'message_id': '1710a580bdfa076e',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="UTF-8"; format=flowed; delsp=yes', 'content_transfer_encoding': 'base64', 'body_size': 577, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="UTF-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4579, 'body_data': ''}],
#  'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#              '[209.85.220.73])        by mx.google.com with SMTPS id '
#              'n105sor10603205ota.115.2020.03.23.19.21.14        for '
#              '<shortpoet@gmail.com>        (Google Transport Security);        '
#              'Mon, 23 Mar 2020 19:21:14 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  '3mm55xggtcvccd-g3eanz11djcih.5dd5a3.1dbh6dgied3i5bz7a.1db@gaia.bounces.google.com '
#                  'designates 209.85.220.73 as permitted sender) '
#                  'client-ip=209.85.220.73;',
#  'size_estimate': '5692846',
#  'subject': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=da23e45287f58e99677dd1beda545b1cc2b9f83e&iid=e315196d8edb4c6799ac813ed275cc17&uid=762420025&nid=244+26&usbid=9>',
#  'thread_id': '1710a03f179e6156'}
# {'date': 'Tue, 24 Mar 2020 01:29:11 +0000 (GMT)',
#  'from_': 'Google <no-reply@accounts.google.com>',
#  'history_id': '1585013351000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#  'list_unsubscribe': 11066,
#  'message_id': '1710a28684d3268d',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="UTF-8"; format=flowed; delsp=yes', 'content_transfer_encoding': 'base64', 'body_size': 583, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="UTF-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4585, 'body_data': ''}],
#  'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#              '[209.85.220.73])        by mx.google.com with SMTPS id '
#              't203sor11701516qke.142.2020.03.23.18.29.12        for '
#              '<shortpoet@gmail.com>        (Google Transport Security);        '
#              'Mon, 23 Mar 2020 18:29:12 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  '3agj5xggtcq001-4r2ybnpp17065.t11tyr.p1z5u14621r6tznvy.p1z@gaia.bounces.google.com '
#                  'designates 209.85.220.73 as permitted sender) '
#                  'client-ip=209.85.220.73;',
#  'size_estimate': '5692846',
#  'subject': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=da23e45287f58e99677dd1beda545b1cc2b9f83e&iid=e315196d8edb4c6799ac813ed275cc17&uid=762420025&nid=244+26&usbid=9>',
#  'thread_id': '1710a03f179e6156'}
# {'date': 'Tue, 24 Mar 2020 01:25:48 +0000 (GMT)',
#  'from_': 'Google <no-reply@accounts.google.com>',
#  'history_id': '1585013148000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#  'list_unsubscribe': 11057,
#  'message_id': '1710a25520d8c749',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="UTF-8"; format=flowed; delsp=yes', 'content_transfer_encoding': 'base64', 'body_size': 582, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="UTF-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4583, 'body_data': ''}],
#  'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#              '[209.85.220.73])        by mx.google.com with SMTPS id '
#              'd12sor12261544qke.124.2020.03.23.18.25.50        for '
#              '<shortpoet@gmail.com>        (Google Transport Security);        '
#              'Mon, 23 Mar 2020 18:25:50 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  '3nmf5xggtcueqr-uhso1dffrxqwv.jrrjoh.frpvkruwsrhwjpdlo.frp@gaia.bounces.google.com '
#                  'designates 209.85.220.73 as permitted sender) '
#                  'client-ip=209.85.220.73;',
#  'size_estimate': '5692846',
#  'subject': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=da23e45287f58e99677dd1beda545b1cc2b9f83e&iid=e315196d8edb4c6799ac813ed275cc17&uid=762420025&nid=244+26&usbid=9>',
#  'thread_id': '1710a03f179e6156'}
# {'date': 'Tue, 24 Mar 2020 00:49:21 +0000 (GMT)',
#  'from_': 'Google <no-reply@accounts.google.com>',
#  'history_id': '1585010961000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#  'list_unsubscribe': 11037,
#  'message_id': '1710a03f179e6156',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="UTF-8"; format=flowed; delsp=yes', 'content_transfer_encoding': 'base64', 'body_size': 573, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="UTF-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4571, 'body_data': ''}],
#  'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#              '[209.85.220.73])        by mx.google.com with SMTPS id '
#              'z144sor20265660pfc.89.2020.03.23.17.49.22        for '
#              '<shortpoet@gmail.com>        (Google Transport Security);        '
#              'Mon, 23 Mar 2020 17:49:22 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  '3ell5xggtcamqr-uhsobdffrxqwv.jrrjoh.frpvkruwsrhwjpdlo.frp@gaia.bounces.google.com '
#                  'designates 209.85.220.73 as permitted sender) '
#                  'client-ip=209.85.220.73;',
#  'size_estimate': '5692846',
#  'subject': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=da23e45287f58e99677dd1beda545b1cc2b9f83e&iid=e315196d8edb4c6799ac813ed275cc17&uid=762420025&nid=244+26&usbid=9>',
#  'thread_id': '1710a03f179e6156'}
# {'date': 'Tue, 24 Mar 2020 00:14:45 +0000',
#  'from_': '"Brasil Brasil Cultural Center & Capoeira Batuque" '
#           '<capoeirabatuque.bbcc@gmail.com>',
#  'history_id': '1585008885000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_UPDATES', 'INBOX'],
#  'list_unsubscribe': 50598,
#  'message_id': '17109e4decb71f2f',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="us-ascii"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 2034, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="us-ascii"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 42544, 'body_data': ''}],
#  'received': 'from localhost (localhost [127.0.0.1]) by '
#              'mail115.wdc01.mcdlv.net (Mailchimp) with ESMTP id '
#              '48mWwM2Cx3z7lmJcj for <shortpoet@gmail.com>; Tue, 24 Mar 2020 '
#              '00:14:59 +0000 (GMT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'bounce-mc.us2_2835378.1365565-8cd2f3c4fd@mail115.wdc01.mcdlv.net '
#                  'designates 205.201.129.115 as permitted sender) '
#                  'client-ip=205.201.129.115;',
#  'size_estimate': '5693339',
#  'subject': '<https://brasilbrasil.us2.list-manage.com/unsubscribe?u=1c298dc70041213bba74d7f5c&id=6cf1e7b99a&e=8cd2f3c4fd&c=5e64a5d8e0>, '
#             '<mailto:unsubscribe-mc.us2_1c298dc70041213bba74d7f5c.5e64a5d8e0-8cd2f3c4fd@mailin.mcsv.net?subject=unsubscribe>',
#  'thread_id': '17109e4decb71f2f'}
# {'date': 'Tue, 24 Mar 2020 00:02:35 +0000',
#  'from_': '"Brasil Brasil Cultural Center & Capoeira Batuque" '
#           '<capoeirabatuque.bbcc@gmail.com>',
#  'history_id': '1585008155000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#  'list_unsubscribe': 47798,
#  'message_id': '17109d975d786a40',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="us-ascii"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 1426, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="us-ascii"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 40406, 'body_data': ''}],
#  'received': 'from localhost (localhost [127.0.0.1]) by '
#              'mail115.wdc01.mcdlv.net (Mailchimp) with ESMTP id '
#              '48mWfG0KRGz7lmcp4 for <shortpoet@gmail.com>; Tue, 24 Mar 2020 '
#              '00:02:46 +0000 (GMT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'bounce-mc.us2_2835378.1365549-8cd2f3c4fd@mail115.wdc01.mcdlv.net '
#                  'designates 205.201.129.115 as permitted sender) '
#                  'client-ip=205.201.129.115;',
#  'size_estimate': '5692844',
#  'subject': '<https://brasilbrasil.us2.list-manage.com/unsubscribe?u=1c298dc70041213bba74d7f5c&id=6cf1e7b99a&e=8cd2f3c4fd&c=3516e47995>, '
#             '<mailto:unsubscribe-mc.us2_1c298dc70041213bba74d7f5c.3516e47995-8cd2f3c4fd@mailin.mcsv.net?subject=unsubscribe>',
#  'thread_id': '17109d975d786a40'}
# {'date': 'Mon, 23 Mar 2020 18:00:00 -0400',
#  'from_': 'Eastern Mountain Sports <easternmountainsports@em.ems.com>',
#  'history_id': '1585000800000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 43770,
#  'message_id': '171096d47778ce36',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 875, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 34574, 'body_data': ''}],
#  'received': 'from localhost (10.0.2.105) by ms157-045.bronto.com id '
#              'hf4p802lr205 for <shortpoet@gmail.com>; Mon, 23 Mar 2020 '
#              '18:01:17 -0400 (envelope-from '
#              '<h2bm38be44d8x7kca2169vxufo47cuyf-b@em.ems.com>)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'h2bm38be44d8x7kca2169vxufo47cuyf-b@em.ems.com designates '
#                  '69.166.157.45 as permitted sender) client-ip=69.166.157.45;',
#  'size_estimate': '5692330',
#  'subject': '<mailto:h2bm38be44d8x7kca2169vxufo47cuyf-u@em.ems.com>, '
#             '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/aosuarredcxzysqvtwvnzbxsdybjbjb?td=4lNIEwTbwycIOq7PFvcP6QE5VqAOusMMkPAx2aGuqmuNf8wjpEsZAnYCTC8kphXyCSvhdVng9oVXxMmRbunbzu1ggh8E2_-zSFtMUawg2zUwrwOGeYUFFtOUgcOfStIsRvV1KLEISeyp8rTHzEe9RtXyI2b8Q7-CzS&tid=23390422374529978492965224838942444356477070271257088774780659352032037690404098>',
#  'thread_id': '171096d47778ce36'}
# {'date': 'Mon, 23 Mar 2020 14:47:18 -0700',
#  'from_': 'Google Cloud Platform <CloudPlatform-noreply@google.com>',
#  'history_id': '1585000038000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#  'list_unsubscribe': 73277,
#  'message_id': '171095d405bd9749',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="UTF-8"; format=flowed; delsp=yes', 'content_transfer_encoding': 'base64', 'body_size': 5973, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="UTF-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 56327, 'body_data': ''}],
#  'received': 'from mail-sor-f69.google.com (mail-sor-f69.google.com. '
#              '[209.85.220.69])        by mx.google.com with SMTPS id '
#              'r85sor11968244ilb.54.2020.03.23.14.47.18        for '
#              '<shortpoet@gmail.com>        (Google Transport Security);        '
#              'Mon, 23 Mar 2020 14:47:18 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  '3zi55xhukcaenmpve0mbugpsn-opsfqmzhpphmf.dpntipsuqpfuhnbjm.dpn@scoutcamp.bounces.google.com '
#                  'designates 209.85.220.69 as permitted sender) '
#                  'client-ip=209.85.220.69;',
#  'size_estimate': '5692843',
#  'subject': '<mailto:h2bm38be44d8x7kca2169vxufo47cuyf-u@em.ems.com>, '
#             '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/aosuarredcxzysqvtwvnzbxsdybjbjb?td=4lNIEwTbwycIOq7PFvcP6QE5VqAOusMMkPAx2aGuqmuNf8wjpEsZAnYCTC8kphXyCSvhdVng9oVXxMmRbunbzu1ggh8E2_-zSFtMUawg2zUwrwOGeYUFFtOUgcOfStIsRvV1KLEISeyp8rTHzEe9RtXyI2b8Q7-CzS&tid=23390422374529978492965224838942444356477070271257088774780659352032037690404098>',
#  'thread_id': '171095d405bd9749'}
# {'date': 'Mon, 23 Mar 2020 21:25:00 +0000 (UTC)',
#  'from_': 'Medium Daily Digest <noreply@medium.com>',
#  'history_id': '1584998700000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#  'list_unsubscribe': 129342,
#  'message_id': '1710948ecc61a70c',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 16821, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 99002, 'body_data': ''}],
#  'received': 'from MTgyMzE0NA (unknown) by ismtpd0023p1iad2.sendgrid.net (SG) '
#              'with HTTP id m-FvjlDITuy5_qGrqjrVCw Mon, 23 Mar 2020 '
#              '21:22:58.381 +0000 (UTC)',
# ...
#  'parts': [],
#  'received': 'from mta409s1.r.groupon.com (mta409s1.r.groupon.com. '
#              '[50.115.211.109])        by mx.google.com with ESMTPS id '
#              'a18si4184217pfh.186.2020.03.20.04.23.58        for '
#              '<shortpoet@gmail.com>        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Fri, 20 '
#              'Mar 2020 04:23:58 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'eb5d3420-23d3-11e2-86db-00259069d5fe@bounce.r.groupon.com '
#                  'designates 50.115.211.109 as permitted sender) '
#                  'client-ip=50.115.211.109;',
#  'size_estimate': '5686960',
#  'subject': '<mailto:eb5d3420-23d3-11e2-86db-00259069d5fe@unsub.r.groupon.com?subject=ZWI1ZDM0MjAtMjNkMy0xMWUyLTg2ZGItMDAyNTkwNjlkNWZlOmJhdGNoOjBlOGFjMjUxLTkwOTUtNDA5NC1hNTQ3LWEyZGJkZmNiZGQ2YV8wXzIwMjAwMzIwOm51bGw6VVM=>',
#  'thread_id': '170f7af8048b0804'}
# {'date': 'Fri, 20 Mar 2020 06:00:00 -0400',
#  'from_': 'Eastern Mountain Sports <easternmountainsports@em.ems.com>',
#  'history_id': '1584698400000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 36747,
#  'message_id': '170f776a3c789d1b',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 875, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 28010, 'body_data': ''}],
#  'received': 'from localhost (10.0.5.34) by ms157-045.bronto.com id '
#              'heick02lr20r for <shortpoet@gmail.com>; Fri, 20 Mar 2020 '
#              '06:06:44 -0400 (envelope-from '
#              '<9uyjp6sgtw7szvarvqmzmy49w7vmwuyf-b@em.ems.com>)',
#  'received_SPF': 'pass (google.com: domain of '
#                  '9uyjp6sgtw7szvarvqmzmy49w7vmwuyf-b@em.ems.com designates '
#                  '69.166.157.45 as permitted sender) client-ip=69.166.157.45;',
#  'size_estimate': '5686895',
#  'subject': '<mailto:9uyjp6sgtw7szvarvqmzmy49w7vmwuyf-u@em.ems.com>, '
#             '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/awkckqnicqmpybyoobryfrkjjfkfbfp?td=Tlw1bcDnbtfX2dgsHCy7oA_rUU95ezB_63PFBIujrGewldF6yUzILOkiOzs1lVexYVKKDzZx5GIPP1j5PBBJRs1Z0IF7fFqOWGoTrbYG0NNutxRhZsSUM5DAP8H9V_zbS39yVXJ_WHfq0gKSyKEcSsJFIU4fJHUqjh&tid=16323239614529978492965224801894839351776012197711881988936504947959067603871489>',
#  'thread_id': '170f776a3c789d1b'}
# {'date': '20 Mar 2020 07:39:37 +0000',
#  'from_': '"Newegg.com" <Promo@promo.newegg.com>',
#  'history_id': '1584689977000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 37224,
#  'message_id': '170f6f663dfe6c43',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4471, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 24975, 'body_data': ''}],
#  'received': 'from nampmer26 (10.24.72.86) by p1-002125.promo.newegg.com id '
#              'hehs6m2bq58s for <shortpoet@gmail.com>; Fri, 20 Mar 2020 '
#              '03:39:37 -0400 (envelope-from <Promo@promo.newegg.com>)',
#  'received_SPF': 'pass (google.com: domain of promo@promo.newegg.com '
#                  'designates 173.213.2.125 as permitted sender) '
#                  'client-ip=173.213.2.125;',
#  'size_estimate': '5686827',
#  'subject': '<mailto:unsubscribe-ae03d6968f481d5f785ac1b5f41f7302@promo.newegg.com?subject=Unsubscribe>',
#  'thread_id': '170f6f663dfe6c43'}
# {'date': 'Fri, 20 Mar 2020 05:15:58 +0000',
#  'from_': 'X-Mirage <x-mirage@x-mirage.com>',
#  'history_id': '1584681358000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 18952,
#  'message_id': '170f65e989c747bf',
#  'parts': [],
#  'received': 'from a11-68.smtp-out.amazonses.com '
#              '(a11-68.smtp-out.amazonses.com. [54.240.11.68])        by '
#              'mx.google.com with ESMTPS id '
#              'd57si2714933qtc.60.2020.03.19.22.15.59        for '
#              '<shortpoet@gmail.com>        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-SHA bits=128/128);        Thu, 19 Mar '
#              '2020 22:15:59 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  '01000170f65e9668-016eb9bf-f55d-4334-a48e-91244e2d3d7a-000000@amazonses.com '
#                  'designates 54.240.11.68 as permitted sender) '
#                  'client-ip=54.240.11.68;',
#  'size_estimate': '5686648',
#  'subject': '<http://news.x-mirage.com/unsubscribe/c9glAJSAXYE2ABSvtWPPVUsF9oS2EQsagveHaHYhWmU/NOhdveOr892DZS1GAE2n7q0g/0UFGt64DNEXGrtkkirTinw>',
#  'thread_id': '170f65e989c747bf'}
# {'date': 'Fri, 20 Mar 2020 02:23:09 +0000',
#  'from_': 'Groupon Goods <noreply@r.groupon.com>',
#  'history_id': '1584670989000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 177519,
#  'message_id': '170f5c063e4bff55',
#  'parts': [],
#  'received': 'from mta433s1.r.groupon.com (mta433s1.r.groupon.com. '
#              '[50.115.211.133])        by mx.google.com with ESMTPS id '
#              'q5si3048030pjq.18.2020.03.19.19.23.10        for '
#              '<shortpoet@gmail.com>        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Thu, 19 '
#              'Mar 2020 19:23:10 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'eb5d3420-23d3-11e2-86db-00259069d5fe@bounce.r.groupon.com '
#                  'designates 50.115.211.133 as permitted sender) '
#                  'client-ip=50.115.211.133;',
#  'size_estimate': '5686584',
#  'subject': '<mailto:eb5d3420-23d3-11e2-86db-00259069d5fe@unsub.r.groupon.com?subject=ZWI1ZDM0MjAtMjNkMy0xMWUyLTg2ZGItMDAyNTkwNjlkNWZlOmJhdGNoOjI4N2QxMDNhLTY2NTgtNDU0Ny1iMDAzLTM2ZTRkMDIxMzg5N18wXzIwMjAwMzE5X3RyZWF0bWVudDA6bnVsbDpVUw==>',
#  'thread_id': '170f5c063e4bff55'}
# {'date': 'Fri, 20 Mar 2020 01:54:25 +0000 (UTC)',
#  'from_': 'MedMen <hello@medmen.com>',
#  'history_id': '1584669265000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 125921,
#  'message_id': '170f5a61326532c5',
#  'parts': [],
#  'received': 'from ip-10-0-1-240.ec2.internal (unknown) by '
#              'ismtpd0090p1mdw1.sendgrid.net (SG) with ESMTP id '
#              'yDFSvaKkQkCSG9q3iANxXA for <sendgrid@clutch.com>; Fri, 20 Mar '
#              '2020 01:53:00.098 +0000 (UTC)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'bounces+7069921-ea2c-shortpoet=gmail.com@em1.medmen.com '
#                  'designates 198.37.145.71 as permitted sender) '
#                  'client-ip=198.37.145.71;',
#  'size_estimate': '5686531',
#  'subject': '<mailto:eb5d3420-23d3-11e2-86db-00259069d5fe@unsub.r.groupon.com?subject=ZWI1ZDM0MjAtMjNkMy0xMWUyLTg2ZGItMDAyNTkwNjlkNWZlOmJhdGNoOjI4N2QxMDNhLTY2NTgtNDU0Ny1iMDAzLTM2ZTRkMDIxMzg5N18wXzIwMjAwMzE5X3RyZWF0bWVudDA6bnVsbDpVUw==>',
#  'thread_id': '170f5a61326532c5'}
# {'date': 'Fri, 20 Mar 2020 12:02:12 +1100',
#  'from_': 'The Broad <info@thebroad.org>',
#  'history_id': '1584666132000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 53066,
#  'message_id': '170f578cb62e4410',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="utf-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 5180, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="utf-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 40549, 'body_data': ''}],
#  'received': 'from mx106.a.outbound.createsend.com '
#              '(mx106.a.outbound.createsend.com. [203.55.21.106])        by '
#              'mx.google.com with ESMTPS id '
#              't136si3073678pgb.39.2020.03.19.18.04.58        for '
#              '<shortpoet@gmail.com>        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Thu, 19 '
#              'Mar 2020 18:04:59 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'thebroad-mjydidk1yduyulljkh1d@cmail20.com designates '
#                  '203.55.21.106 as permitted sender) client-ip=203.55.21.106;',
#  'size_estimate': '5686449',
#  'subject': '<http://unsub.cmail20.com/t/d-u-mjydidk-yduyulljkh/>, '
#             '<mailto:unsubscribe-mjydidk2yduyulljkh2d-7974D761@cmail20.com?subject=Unsubscribe>',
#  'thread_id': '170f578cb62e4410'}
# {'date': 'Thu, 19 Mar 2020 17:30:44 -0600',
#  'from_': 'Hulu <hulu@hulumail.com>',
#  'history_id': '1584660644000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 81870,
#  'message_id': '170f5260c7b763cb',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="utf-8"', 'content_transfer_encoding': '8bit', 'body_size': 6426, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="utf-8"', 'content_transfer_encoding': '8bit', 'body_size': 70831, 'body_data': ''}],
#  'received': 'by mta17.hulumail.com id heg0oo2fmd4t for <shortpoet@gmail.com>; '
#              'Thu, 19 Mar 2020 23:30:44 +0000 (envelope-from '
#              '<bounce-48_HTML-609757074-4246979-1064447-6937@bounce.hulumail.com>)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'bounce-48_html-609757074-4246979-1064447-6937@bounce.hulumail.com '
#                  'designates 13.111.102.14 as permitted sender) '
#                  'client-ip=13.111.102.14;',
#  'size_estimate': '5686378',
#  'subject': '<mailto:leave-fd7f10781a3c402029-fe2212707c63017a751374-fe86107271620d7a7c-fe9515707360007972-ff2612797663@leave.hulumail.com>',
#  'thread_id': '170f5260c7b763cb'}
# {'date': 'Thu, 19 Mar 2020 18:00:00 -0400',
#  'from_': 'Eastern Mountain Sports <easternmountainsports@em.ems.com>',
#  'history_id': '1584655200000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 40087,
#  'message_id': '170f4d84cb38b7a2',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 875, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=utf-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 31158, 'body_data': ''}],
#  'received': 'from localhost (10.0.4.169) by ms157-045.bronto.com id '
#              'hefmq82lr20q for <shortpoet@gmail.com>; Thu, 19 Mar 2020 '
#              '18:01:15 -0400 (envelope-from '
#              '<j5563e4rmkmek840oc9lawj10x5nmuyf-b@em.ems.com>)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'j5563e4rmkmek840oc9lawj10x5nmuyf-b@em.ems.com designates '
#                  '69.166.157.45 as permitted sender) client-ip=69.166.157.45;',
#  'size_estimate': '5686308',
#  'subject': '<mailto:j5563e4rmkmek840oc9lawj10x5nmuyf-u@em.ems.com>, '
#             '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/bxuoytxkqbtmxdlqsczugfxnzgehbeg?td=LzD63GPtrnKcPHRdsoX4oAzeVlkU5UXKB0ve3oo6oMN8OKj1iZX9BiiHPEPWG00JiLgdRfAIT1AmhWRiVgzwaD-XYlSzcz_o8pJjsHDopcbwnZYyKnHQ1xqjT2xZ0TmBI0i7-AoLRcu0DwjIQXN8RlVf5t3ZddpQCR&tid=37088725374529978492965224834441019313497889283189739522650782414603883529891074>',
#  'thread_id': '170f4d84cb38b7a2'}
# {'date': 'Thu, 19 Mar 2020 22:06:13 +0000',
#  'from_': 'INFOLIST <jeffgund@infolist.com>',
#  'history_id': '1584655573000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 124860,
#  'message_id': '170f4d5b0ab03e36',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="utf-8"; format="fixed"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 8498, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="utf-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 101498, 'body_data': ''}],
#  'received': 'from localhost (localhost [127.0.0.1]) by mail78.sea41.rsgsv.net '
#              '(Mailchimp) with ESMTP id 48k1Fp4GHhz6CQZZ2 for '
#              '<shortpoet@gmail.com>; Thu, 19 Mar 2020 22:06:22 +0000 (GMT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'bounce-mc.us15_72942930.485587-2756a70a0a@mail78.sea41.rsgsv.net '
#                  'designates 148.105.13.78 as permitted sender) '
#                  'client-ip=148.105.13.78;',
#  'size_estimate': '5686254',
#  'subject': '<https://INFOLIST.us15.list-manage.com/unsubscribe?u=83c3401736a63b44b3f05de50&id=a19f01dc9f&e=2756a70a0a&c=abfe75b361>, '
#             '<mailto:unsubscribe-mc.us15_83c3401736a63b44b3f05de50.abfe75b361-2756a70a0a@mailin.mcsv.net?subject=unsubscribe>',
#  'thread_id': '170f4d5b0ab03e36'}
# {'date': 'Thu, 19 Mar 2020 21:57:22 +0000',
#  'from_': 'Twitter <notify@twitter.com>',
#  'history_id': '1584655042000',
#  'internal_date': '',
#  'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#  'list_unsubscribe': 25629,
#  'message_id': '170f4cd092a0b833',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=UTF-8', 'content_transfer_encoding': '7bit', 'body_size': 806, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 16718, 'body_data': ''}],
#  'received': 'from spruce-goose-aa.twitter.com (spruce-goose-aa.twitter.com. '
#              '[199.59.150.70])        by mx.google.com with ESMTPS id '
#              'q80si2824823pfc.252.2020.03.19.14.57.22        for '
#              '<shortpoet@gmail.com>        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Thu, 19 '
#              'Mar 2020 14:57:22 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'n0340ae2eb0-2e887b48fb9d4364-shortpoet===gmail.com@bounce.twitter.com '
#                  'designates 199.59.150.70 as permitted sender) '
#                  'client-ip=199.59.150.70;',
#  'size_estimate': '5690029',
#  'subject': '<https://twitter.com/i/u?t=1&listunsub=t&cn=YWN0aXZpdHlfZGlnZXN0X3dpdGhfaGVhZGxpbmVfY2hhbmdl&sig=382eb5798694be3b1a04437ce44135857f31efa4&iid=2e887b48fb9d4364988adc7fa9a02c56&uid=762420025&nid=244+26&usbid=16>',
#  'thread_id': '170f4cd092a0b833'}
# {'date': 'Fri, 20 Mar 2020 08:00:22 +1100',
#  'from_': 'Serious Eats <newsletter@seriouseats.com>',
#  'history_id': '1584651622000',
#  'internal_date': '',
#  'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#  'list_unsubscribe': 55075,
#  'message_id': '170f49c8a42e0a3c',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset="utf-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 2806, 'body_data': ''},
#            {'mime_type': 'text/html', 'content_type': 'text/html; charset="utf-8"', 'content_transfer_encoding': 'quoted-printable', 'body_size': 45011, 'body_data': ''}],
#  'received': 'from mx33.b.outbound.createsend.com '
#              '(mx33.b.outbound.createsend.com. [27.126.146.33])        by '
#              'mx.google.com with ESMTPS id '
#              'j11si2691227pgk.9.2020.03.19.14.04.23        for '
#              '<shortpoet@gmail.com>        (version=TLS1_2 '
#              'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Thu, 19 '
#              'Mar 2020 14:04:24 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of '
#                  'seriouseats-mjjtra1utiltllyd1d@cmail19.com designates '
#                  '27.126.146.33 as permitted sender) client-ip=27.126.146.33;',
#  'size_estimate': '5686111',
#  'subject': '<http://unsub.cmail19.com/t/d-u-mjjtra-utiltllyd/>, '
#             '<mailto:unsubscribe-mjjtra2utiltllyd2d-3B25DDC7@cmail19.com?subject=Unsubscribe>',
#  'thread_id': '170f49c8a42e0a3c'}

# %%
#_part = None

# %%
#_part

# %%
#_message = None

# %%
#for m in messages:
#    m.parts = None

# %%
vars(messages[0])
# Out:
# {'message_id': '17112b1ce27fcb66',
#  'thread_id': '17112b1ce27fcb66',
#  'label_ids': ['UNREAD', 'CATEGORY_SOCIAL', 'INBOX'],
#  'date': 'Wed, 25 Mar 2020 17:16:14 +0000',
#  'from_': 'Twitter <info@twitter.com>',
#  'received': 'from spruce-goose-ah.twitter.com (spruce-goose-ah.twitter.com. [199.59.150.77])        by mx.google.com with ESMTPS id x12si16129823pgi.105.2020.03.25.10.16.14        for <shortpoet@gmail.com>        (version=TLS1_2 cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Wed, 25 Mar 2020 10:16:15 -0700 (PDT)',
#  'received_SPF': 'pass (google.com: domain of n03460b90bd-e8b1b18795dd4786-shortpoet===gmail.com@bounce.twitter.com designates 199.59.150.77 as permitted sender) client-ip=199.59.150.77;',
#  'subject': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=fa8f10c87ca6fd093fbd6710d052ab9d02de291d&iid=e8b1b18795dd4786acf50e5c35453e12&uid=762420025&nid=244+26&usbid=9>',
#  'list_unsubscribe': 100980,
#  'size_estimate': '5695266',
#  'history_id': '1585156574000',
#  'internal_date': '',
#  'parts': [{'mime_type': 'text/plain', 'content_type': 'text/plain; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 4188, 'body_data': ''},
#   {'mime_type': 'text/html', 'content_type': 'text/html; charset=UTF-8', 'content_transfer_encoding': 'quoted-printable', 'body_size': 84518, 'body_data': ''}]}

# %%
pprint(messages)
# Out:
# [{'date': 'Wed, 25 Mar 2020 18:00:00 -0400',
#   'from_': 'Eastern Mountain Sports <easternmountainsports@em.ems.com>',
#   'history_id': '5695467',
#   'internal_date': '1585173600000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:a1ei32lf0jagww8y3m2u21xdlc6h9uyf-u@em.ems.com>, '
#                       '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/cabmjrugurilmsngsranbtphcbwpbjj?td=NPp9ub-jT4SC5YXNOyyaAQD4xxqNzUza-qRwhVszzuQMAtXDVU3S7GSGPsNPigDMxDOL2ZQayxukrOg-QsFBaToXgb0v-wwDFoXf8ei5L-EhauYMmpZSc95Hq4i7F2pSVaVxKRFNOEUvXq16wgzxmiDwZlE1F3iHuz&tid=09606102584529978492965224813883537282801408835736708704358616420757409261405186>',
#   'message_id': '17113be362a6f56f',
#   'parts': [{'body_size': 875,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=utf-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 34059,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=utf-8',
#              'mime_type': 'text/html'}],
#   'received': 'from localhost (10.0.2.67) by ms157-045.bronto.com id '
#               'hffb9a2lr20n for <shortpoet@gmail.com>; Wed, 25 Mar 2020 '
#               '18:02:55 -0400 (envelope-from '
#               '<a1ei32lf0jagww8y3m2u21xdlc6h9uyf-b@em.ems.com>)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'a1ei32lf0jagww8y3m2u21xdlc6h9uyf-b@em.ems.com designates '
#                   '69.166.157.45 as permitted sender) client-ip=69.166.157.45;',
#   'size_estimate': 43195,
#   'subject': 'NEW Techwick Peak Essentials & Essence!',
#   'thread_id': '17113be362a6f56f'},
#  {'date': 'Wed, 25 Mar 2020 17:16:14 +0000',
#   'from_': 'Twitter <info@twitter.com>',
#   'history_id': '5695266',
#   'internal_date': '1585156574000',
#   'label_ids': ['UNREAD', 'CATEGORY_SOCIAL', 'INBOX'],
#   'list_unsubscribe': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=fa8f10c87ca6fd093fbd6710d052ab9d02de291d&iid=e8b1b18795dd4786acf50e5c35453e12&uid=762420025&nid=244+26&usbid=9>',
#   'message_id': '17112b1ce27fcb66',
#   'parts': [{'body_size': 4188,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=UTF-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 84518,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=UTF-8',
#              'mime_type': 'text/html'}],
#   'received': 'from spruce-goose-ah.twitter.com (spruce-goose-ah.twitter.com. '
#               '[199.59.150.77])        by mx.google.com with ESMTPS id '
#               'x12si16129823pgi.105.2020.03.25.10.16.14        for '
#               '<shortpoet@gmail.com>        (version=TLS1_2 '
#               'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Wed, '
#               '25 Mar 2020 10:16:15 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'n03460b90bd-e8b1b18795dd4786-shortpoet===gmail.com@bounce.twitter.com '
#                   'designates 199.59.150.77 as permitted sender) '
#                   'client-ip=199.59.150.77;',
#   'size_estimate': 100980,
#   'subject': 'David Babbott-Klein shared "Trapped at Sea by Covid-19 '
#              'Lockdowns, Cr...',
#   'thread_id': '17112b1ce27fcb66'},
#  {'date': 'Wed, 25 Mar 2020 08:00:00 -0700',
#   'from_': 'The Clymb <events@theclymb.com>',
#   'history_id': '5695195',
#   'internal_date': '1585148400000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'INBOX'],
#   'list_unsubscribe': '<mailto:list-unsubscribe@theclymb.com?subject=unsubscribe>',
#   'message_id': '171125a020c89b0a',
#   'parts': [{'body_size': 1050,
#              'content_transfer_encoding': '8bit',
#              'content_type': 'text/plain; charset=utf-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 33995,
#              'content_transfer_encoding': '8bit',
#              'content_type': 'text/html; charset=utf-8',
#              'mime_type': 'text/html'}],
#   'received': 'by mta-em8.theclymb.com id hfdtlu2dh1ke for '
#               '<shortpoet@gmail.com>; Wed, 25 Mar 2020 07:43:49 -0700 '
#               '(envelope-from <events@theclymb.com>)',
#   'received_SPF': 'pass (google.com: domain of events@theclymb.com designates '
#                   '74.82.137.57 as permitted sender) client-ip=74.82.137.57;',
#   'size_estimate': 39142,
#   'subject': "Here's an Extra 25% Off Sitewide",
#   'thread_id': '171125a020c89b0a'},
#  {'date': 'Wed, 25 Mar 2020 13:00:00 +0000 (UTC)',
#   'from_': 'Medium Daily Digest <noreply@medium.com>',
#   'history_id': '5695110',
#   'internal_date': '1585141200000',
#   'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#   'message_id': '17111c80daba19e3',
#   'parts': [{'body_size': 17282,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=UTF-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 99866,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=UTF-8',
#              'mime_type': 'text/html'}],
#   'received': 'from MTgyMzE0NA (unknown) by ismtpd0033p1mdw1.sendgrid.net (SG) '
#               'with HTTP id 94jifWo1Tnqr_cd9wLxDmg Wed, 25 Mar 2020 '
#               '08:12:31.703 +0000 (UTC)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'bounces+1823144-4c20-shortpoet=gmail.com@email.medium.com '
#                   'designates 167.89.47.62 as permitted sender) '
#                   'client-ip=167.89.47.62;',
#   'size_estimate': 130679,
#   'subject': 'How To Set Up Your Mac For Focused Work | Niklas Göke in Better '
#              'Humans',
#   'thread_id': '17111c80daba19e3'},
#  {'date': 'Wed, 25 Mar 2020 06:00:00 -0400',
#   'from_': 'Eastern Mountain Sports <easternmountainsports@em.ems.com>',
#   'history_id': '5694884',
#   'internal_date': '1585130400000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:bkg5c8d147yy4aj7jqmb6tlduh1o1uyf-u@em.ems.com>, '
#                       '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/aqbmeqgiqcndapefhrcvjypuuucsbhn?td=bxc51SEykYFM-O9ll2pktAVnC4pS3utG4W_crDja2BzZ7tMv5_RHjTStpDpmlwi5-thnbR42fk2Fnh2ikx-Q6h1UcRBXbp7wRphbvNSsXGZdi8HyuI3_SBqeD4gPdAHoy9sLH4-lI11KgIQSBlU_0H-iXTiKIRbqZq&tid=36032205374529978492965224813135248444487986541616422078465637885513106377123585>',
#   'message_id': '17111340e74a3e9b',
#   'parts': [{'body_size': 875,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=utf-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 28120,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=utf-8',
#              'mime_type': 'text/html'}],
#   'received': 'from localhost (10.0.2.97) by ms157-045.bronto.com id '
#               'hfco282lr20e for <shortpoet@gmail.com>; Wed, 25 Mar 2020 '
#               '06:06:07 -0400 (envelope-from '
#               '<bkg5c8d147yy4aj7jqmb6tlduh1o1uyf-b@em.ems.com>)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'bkg5c8d147yy4aj7jqmb6tlduh1o1uyf-b@em.ems.com designates '
#                   '69.166.157.45 as permitted sender) client-ip=69.166.157.45;',
#   'size_estimate': 36939,
#   'subject': '🔵Daily Deal: 60-70% OFF ALL EMS Pants',
#   'thread_id': '17111340e74a3e9b'},
#  {'date': '25 Mar 2020 07:36:49 +0000',
#   'from_': '"Newegg.com" <Promo@promo.newegg.com>',
#   'history_id': '5694811',
#   'internal_date': '1585121809000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:unsubscribe-d9dd0021f276fca3fafbbfa410531ee5@promo.newegg.com?subject=Unsubscribe>',
#   'message_id': '17110adeff87e35c',
#   'parts': [{'body_size': 4382,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=utf-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 22367,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=utf-8',
#              'mime_type': 'text/html'}],
#   'received': 'from nampmer22 (10.24.72.82) by p1-002126.promo.newegg.com id '
#               'hfc6ss2bq58a for <shortpoet@gmail.com>; Wed, 25 Mar 2020 '
#               '03:36:49 -0400 (envelope-from <Promo@promo.newegg.com>)',
#   'received_SPF': 'pass (google.com: domain of promo@promo.newegg.com '
#                   'designates 173.213.2.126 as permitted sender) '
#                   'client-ip=173.213.2.126;',
#   'size_estimate': 34238,
#   'subject': 'Ultimate Gaming Sale – Up to 50% Off',
#   'thread_id': '17110adeff87e35c'},
#  {'date': 'Wed, 25 Mar 2020 05:15:59 +0000',
#   'from_': 'X-Mirage <x-mirage@x-mirage.com>',
#   'history_id': '5694694',
#   'internal_date': '1585113359000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<http://news.x-mirage.com/unsubscribe/c9glAJSAXYE2ABSvtWPPVUsF9oS2EQsagveHaHYhWmU/NOhdveOr892DZS1GAE2n7q0g/RJjmqNrTpfADmlxbCHkxNQ>',
#   'message_id': '171101e651aa226d',
#   'parts': [],
#   'received': 'from a11-62.smtp-out.amazonses.com '
#               '(a11-62.smtp-out.amazonses.com. [54.240.11.62])        by '
#               'mx.google.com with ESMTPS id '
#               'o5si7468431qkb.11.2020.03.24.22.15.59        for '
#               '<shortpoet@gmail.com>        (version=TLS1_2 '
#               'cipher=ECDHE-RSA-AES128-SHA bits=128/128);        Tue, 24 Mar '
#               '2020 22:15:59 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   '01000171101e63e0-cac16fa5-84d5-40f1-a6d0-995a62164b27-000000@amazonses.com '
#                   'designates 54.240.11.62 as permitted sender) '
#                   'client-ip=54.240.11.62;',
#   'size_estimate': 18845,
#   'subject': 'Boost Your Work From Home Productivity With Pagico 9: Task & '
#              'Data Management Software (50% off)',
#   'thread_id': '171101e651aa226d'},
#  {'date': 'Wed, 25 Mar 2020 02:09:22 +0000',
#   'from_': 'Twitter <info@twitter.com>',
#   'history_id': '5694623',
#   'internal_date': '1585102162000',
#   'label_ids': ['UNREAD', 'CATEGORY_SOCIAL', 'INBOX'],
#   'list_unsubscribe': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=6d72196c554b55c986a0529e0007848634b367da&iid=ffd1f27f26734468bb93706e9336621c&uid=762420025&nid=244+26&usbid=9>',
#   'message_id': '1710f738c9b989c6',
#   'parts': [{'body_size': 4126,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=UTF-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 84523,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=UTF-8',
#              'mime_type': 'text/html'}],
#   'received': 'from spruce-goose-al.twitter.com (spruce-goose-al.twitter.com. '
#               '[199.59.150.81])        by mx.google.com with ESMTPS id '
#               'd12si15038027pgt.114.2020.03.24.19.09.22        for '
#               '<shortpoet@gmail.com>        (version=TLS1_2 '
#               'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Tue, '
#               '24 Mar 2020 19:09:23 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'n0346c4c4e7-ffd1f27f26734468-shortpoet===gmail.com@bounce.twitter.com '
#                   'designates 199.59.150.81 as permitted sender) '
#                   'client-ip=199.59.150.81;',
#   'size_estimate': 100867,
#   'subject': 'David Babbott-Klein shared "Voting by Mail Would Reduce '
#              'Coronavirus ...',
#   'thread_id': '1710f738c9b989c6'},
#  {'date': 'Wed, 25 Mar 2020 01:04:02 +0000',
#   'from_': 'Reddit <noreply@redditmail.com>',
#   'history_id': '5695109',
#   'internal_date': '1585098242000',
#   'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#   'message_id': '1710f37bea23792c',
#   'parts': [],
#   'received': 'from a30-210.smtp-out.amazonses.com '
#               '(a30-210.smtp-out.amazonses.com. [54.240.30.210])        by '
#               'mx.google.com with ESMTPS id '
#               'o15si11389645qtk.236.2020.03.24.18.04.03        for '
#               '<shortpoet@gmail.com>        (version=TLS1_2 '
#               'cipher=ECDHE-RSA-AES128-SHA bits=128/128);        Tue, 24 Mar '
#               '2020 18:04:03 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   '010001710f37bb5f-aeb1ee86-29ba-404d-b9d6-282f8de24277-000000@amazonses.com '
#                   'designates 54.240.30.210 as permitted sender) '
#                   'client-ip=54.240.30.210;',
#   'size_estimate': 108084,
#   'subject': '"If you remember this then chances are you\'ll..."',
#   'thread_id': '1710f37bea23792c'},
#  {'date': 'Wed, 25 Mar 2020 01:01:55 +0000 (GMT)',
#   'from_': 'Google <no-reply@accounts.google.com>',
#   'history_id': '5695108',
#   'internal_date': '1585098115000',
#   'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#   'message_id': '1710f35d099f1ae1',
#   'parts': [{'body_size': 573,
#              'content_transfer_encoding': 'base64',
#              'content_type': 'text/plain; charset="UTF-8"; format=flowed; '
#                              'delsp=yes',
#              'mime_type': 'text/plain'},
#             {'body_size': 4575,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset="UTF-8"',
#              'mime_type': 'text/html'}],
#   'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#               '[209.85.220.73])        by mx.google.com with SMTPS id '
#               'm66sor14659780qkd.149.2020.03.24.18.01.57        for '
#               '<shortpoet@gmail.com>        (Google Transport '
#               'Security);        Tue, 24 Mar 2020 18:01:57 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   '3hk16xggtccmwx-0nyu7jllx3w21.pxxpun.lxv1qx02yxn2pvjru.lxv@gaia.bounces.google.com '
#                   'designates 209.85.220.73 as permitted sender) '
#                   'client-ip=209.85.220.73;',
#   'size_estimate': 11030,
#   'subject': 'Security alert',
#   'thread_id': '1710e8e0c39d7669'},
#  {'date': 'Wed, 25 Mar 2020 00:28:14 +0000 (GMT)',
#   'from_': 'Google <no-reply@accounts.google.com>',
#   'history_id': '5695108',
#   'internal_date': '1585096094000',
#   'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#   'message_id': '1710f16f868f42d0',
#   'parts': [{'body_size': 576,
#              'content_transfer_encoding': 'base64',
#              'content_type': 'text/plain; charset="UTF-8"; format=flowed; '
#                              'delsp=yes',
#              'mime_type': 'text/plain'},
#             {'body_size': 4577,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset="UTF-8"',
#              'mime_type': 'text/html'}],
#   'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#               '[209.85.220.73])        by mx.google.com with SMTPS id '
#               'dl5sor5751163qvb.4.2020.03.24.17.28.16        for '
#               '<shortpoet@gmail.com>        (Google Transport '
#               'Security);        Tue, 24 Mar 2020 17:28:16 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   '3n6v6xggtcc478-by95iuww8e7dc.08805y.w86c18bd98yd06u25.w86@gaia.bounces.google.com '
#                   'designates 209.85.220.73 as permitted sender) '
#                   'client-ip=209.85.220.73;',
#   'size_estimate': 11033,
#   'subject': 'Security alert',
#   'thread_id': '1710e8e0c39d7669'},
#  {'date': 'Tue, 24 Mar 2020 23:54:02 +0000',
#   'from_': 'PayPal <paypal@mail.paypal.com>',
#   'history_id': '5694384',
#   'internal_date': '1585094042000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:bounce-HP2v4000001710ef7a3da91f1b26e96639818073@mail.paypal.com?subject=list-unsubscribe>',
#   'message_id': '1710ef7c102feb08',
#   'parts': [{'body_size': 1898,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=UTF-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 62333,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=UTF-8',
#              'mime_type': 'text/html'}],
#   'received': 'from [10.233.84.191] ([10.233.84.191:41060]) by pc1udsmtn1n12 '
#               '(envelope-from <bounce@mail.paypal.com>) (ecelerity 3.6.9.48312 '
#               'r(Core:3.6.9.0)) with ECSTREAM id 41/E2-37514-A9D9A7E5; Tue, 24 '
#               'Mar 2020 23:54:02 +0000',
#   'received_SPF': 'pass (google.com: domain of bounce@mail.paypal.com '
#                   'designates 142.54.244.111 as permitted sender) '
#                   'client-ip=142.54.244.111;',
#   'size_estimate': 73838,
#   'subject': 'A Message from PayPal’s President and CEO, Dan Schulman',
#   'thread_id': '1710ef7c102feb08'},
#  {'date': '24 Mar 2020 22:39:40 +0000',
#   'from_': '"Newegg.com" <Promo@promo.newegg.com>',
#   'history_id': '5694316',
#   'internal_date': '1585089580000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:unsubscribe-0f032f8924d29f568835b85c05bfe6e0@promo.newegg.com?subject=Unsubscribe>',
#   'message_id': '1710eb871fc902a1',
#   'parts': [{'body_size': 3672,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=utf-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 39154,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=utf-8',
#              'mime_type': 'text/html'}],
#   'received': 'from nampmer28 (10.24.72.88) by p1-002129.promo.newegg.com id '
#               'hfa6mo2bq582 for <shortpoet@gmail.com>; Tue, 24 Mar 2020 '
#               '18:39:40 -0400 (envelope-from <Promo@promo.newegg.com>)',
#   'received_SPF': 'pass (google.com: domain of promo@promo.newegg.com '
#                   'designates 173.213.2.129 as permitted sender) '
#                   'client-ip=173.213.2.129;',
#   'size_estimate': 52471,
#   'subject': 'Trending: $124.99 ASUS 27" FHD Ultra Slim Bezel LED IPS Monitor',
#   'thread_id': '1710eb871fc902a1'},
#  {'date': 'Tue, 24 Mar 2020 18:00:00 -0400',
#   'from_': 'Eastern Mountain Sports <easternmountainsports@em.ems.com>',
#   'history_id': '5694244',
#   'internal_date': '1585087200000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:koynis6s924cip7ikqjl099locgdauyf-u@em.ems.com>, '
#                       '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/anlkekrvpsrfelotymarppyqmnqobah?td=WmNxo64PjUoLVfHZxupd5QDqlZS0DDv4bXXBKQGUafGk1b5XJZKbGRIKvWXj2lLUcGp7F-E0OU3LCbQb9EHd6u6bB7L1ibKN2gwWrd1YPFLXK1Db1m6jcZPgL2T9AiMof2V4nFlbSg6_j8qXjOBpyuw6qlrPyXL2uy&tid=00467544404529978492965224817246452550299816450523387446410344307483509656907010>',
#   'message_id': '1710e9e2784872e1',
#   'parts': [{'body_size': 875,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=utf-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 32874,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=utf-8',
#              'mime_type': 'text/html'}],
#   'received': 'from localhost (10.0.2.94) by ms157-045.bronto.com id '
#               'hfa3b22lr20g for <shortpoet@gmail.com>; Tue, 24 Mar 2020 '
#               '18:02:54 -0400 (envelope-from '
#               '<koynis6s924cip7ikqjl099locgdauyf-b@em.ems.com>)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'koynis6s924cip7ikqjl099locgdauyf-b@em.ems.com designates '
#                   '69.166.157.45 as permitted sender) client-ip=69.166.157.45;',
#   'size_estimate': 41909,
#   'subject': '☆NEW☆ EMS Graphic Tees',
#   'thread_id': '1710e9e2784872e1'},
#  {'date': 'Tue, 24 Mar 2020 21:58:41 +0000 (GMT)',
#   'from_': 'Google <no-reply@accounts.google.com>',
#   'history_id': '5694234',
#   'internal_date': '1585087121000',
#   'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#   'message_id': '1710e8e0c39d7669',
#   'parts': [{'body_size': 572,
#              'content_transfer_encoding': 'base64',
#              'content_type': 'text/plain; charset="UTF-8"; format=flowed; '
#                              'delsp=yes',
#              'mime_type': 'text/plain'},
#             {'body_size': 4573,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset="UTF-8"',
#              'mime_type': 'text/html'}],
#   'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#               '[209.85.220.73])        by mx.google.com with SMTPS id '
#               'z11sor11304793ioz.41.2020.03.24.14.58.41        for '
#               '<shortpoet@gmail.com>        (Google Transport '
#               'Security);        Tue, 24 Mar 2020 14:58:42 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   '3kyj6xggtcxolm-pcnjwyaamslrq.emmejc.amkqfmprnmcrekygj.amk@gaia.bounces.google.com '
#                   'designates 209.85.220.73 as permitted sender) '
#                   'client-ip=209.85.220.73;',
#   'size_estimate': 11033,
#   'subject': 'Security alert',
#   'thread_id': '1710e8e0c39d7669'},
#  {'date': 'Tue, 24 Mar 2020 14:00:00 -0700',
#   'from_': 'The Clymb <events@theclymb.com>',
#   'history_id': '5695119',
#   'internal_date': '1585083600000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:list-unsubscribe@theclymb.com?subject=unsubscribe>',
#   'message_id': '1710e78830f68edc',
#   'parts': [{'body_size': 1051,
#              'content_transfer_encoding': '8bit',
#              'content_type': 'text/plain; charset=utf-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 34015,
#              'content_transfer_encoding': '8bit',
#              'content_type': 'text/html; charset=utf-8',
#              'mime_type': 'text/html'}],
#   'received': 'by mta-em11.theclymb.com id hf9ugo2dh1ka for '
#               '<shortpoet@gmail.com>; Tue, 24 Mar 2020 13:36:47 -0700 '
#               '(envelope-from <events@theclymb.com>)',
#   'received_SPF': 'pass (google.com: domain of events@theclymb.com designates '
#                   '74.82.137.60 as permitted sender) client-ip=74.82.137.60;',
#   'size_estimate': 39085,
#   'subject': 'Extra 25% Off Sale Starts Now',
#   'thread_id': '1710e78830f68edc'},
#  {'date': 'Tue, 24 Mar 2020 20:33:25 +0000',
#   'from_': 'Embassy Suites Niagara Falls Fallsview <noreply@touchbasemail.net>',
#   'history_id': '5694066',
#   'internal_date': '1585082005000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': 'https://clients.touchbasemail.net/subscriptions/unsubscribe/6eedf8a4-d2dc-4d6a-bece-8b6163e20a63/dff0c2cc-6c6d-431e-ace4-8398dceed3fa',
#   'message_id': '1710e3ff8bae78bf',
#   'parts': [{'body_size': 273,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=UTF-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 7885,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=UTF-8',
#              'mime_type': 'text/html'}],
#   'received': 'from notl1-mailer-758c0f21.touchbasemail.net '
#               '(notl1-mailer-758c0f21.touchbasemail.net. '
#               '[2606:5480:1050:3:f833:e9ff:fe68:c0c8])        by mx.google.com '
#               'with ESMTPS id d3si3571505qkk.176.2020.03.24.13.33.25        '
#               'for <shortpoet@gmail.com>        (version=TLS1_2 '
#               'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Tue, '
#               '24 Mar 2020 13:33:25 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'bounces+6eedf8a4-d2dc-4d6a-bece-8b6163e20a63.dff0c2cc-6c6d-431e-ace4-8398dceed3fa@touchbasemail.net '
#                   'designates 2606:5480:1050:3:f833:e9ff:fe68:c0c8 as '
#                   'permitted sender) '
#                   'client-ip=2606:5480:1050:3:f833:e9ff:fe68:c0c8;',
#   'size_estimate': 13809,
#   'subject': 'All-Inclusive Getaway from $199',
#   'thread_id': '1710e3ff8bae78bf'},
#  {'date': 'Tue, 24 Mar 2020 15:19:40 -0500',
#   'from_': 'Carlos Soriano <shortpoet@gmail.com>',
#   'history_id': '5695042',
#   'internal_date': '1585081180000',
#   'label_ids': ['SENT'],
#   'message_id': '1710e3361e3e7719',
#   'parts': [{'body_size': 79,
#              'content_type': 'text/plain; charset="UTF-8"',
#              'mime_type': 'text/plain'},
#             {'body_size': 211,
#              'content_type': 'text/html; charset="UTF-8"',
#              'mime_type': 'text/html'}],
#   'size_estimate': 802,
#   'subject': '',
#   'thread_id': '1710e333d5d9caa9'},
#  {'date': 'Tue, 24 Mar 2020 15:16:06 -0500 (CDT)',
#   'from_': '"DevRel @ Okta" <devcommunity@reply.okta.com>',
#   'history_id': '5693981',
#   'internal_date': '1585080966000',
#   'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#   'list_unsubscribe': '<mailto:JFAXEV3LLFDGU6RVKAYEUVD2PB2DQ4RVJZ2WGVTMKQ3UMY2ZIRCDQVTQNA3HU5CSJE2DAPI.442611.58721.9@unsub-ab.mktomail.com>',
#   'message_id': '1710e3039cc09e09',
#   'parts': [{'body_size': 5349,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=UTF-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 59507,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=UTF-8',
#              'mime_type': 'text/html'}],
#   'received': 'from [10.1.87.249] ([10.1.87.249:51680] '
#               'helo=abmas03.marketo.org) by abmta15.marketo.org (envelope-from '
#               '<devcommunity@reply.okta.com>) (ecelerity 4.2.38.62370 r(:)) '
#               'with ESMTP id F0/AA-04013-68A6A7E5; Tue, 24 Mar 2020 15:16:06 '
#               '-0500',
#   'received_SPF': 'pass (google.com: domain of '
#                   '380-nlu-416.0.442611.0.0.58721.9.18172360@find.okta.com '
#                   'designates 192.28.150.151 as permitted sender) '
#                   'client-ip=192.28.150.151;',
#   'size_estimate': 76041,
#   'subject': 'GraphQL, PKCE, Angular Material, Gatsby, and C# 8.0',
#   'thread_id': '1710e3039cc09e09'},
#  {'date': 'Tue, 24 Mar 2020 13:47:25 -0500',
#   'from_': 'Carlos Soriano <soriano.carlos@gmail.com>',
#   'history_id': '5693913',
#   'internal_date': '1585075645000',
#   'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#   'message_id': '1710ddef6b905652',
#   'parts': [{'body_size': 4,
#              'content_transfer_encoding': '7bit',
#              'content_type': 'text/plain; charset=us-ascii',
#              'mime_type': 'text/plain'},
#             {'body_size': 364804,
#              'content_transfer_encoding': 'base64',
#              'content_type': 'image/jpeg; name=Image-1.jpg; '
#                              'x-apple-part-url=82291A16-A982-46A2-829D-485EA739028C',
#              'mime_type': 'image/jpeg'},
#             {'body_size': 23,
#              'content_transfer_encoding': '7bit',
#              'content_type': 'text/plain; charset=us-ascii',
#              'mime_type': 'text/plain'}],
#   'received': 'from ?IPv6:2600:6c40:200:3539:3071:f518:9b83:8783? '
#               '([2600:6c40:200:3539:3071:f518:9b83:8783])        by '
#               'smtp.gmail.com with ESMTPSA id '
#               'a136sm1479401qkb.15.2020.03.24.11.47.26        (version=TLS1_2 '
#               'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Tue, '
#               '24 Mar 2020 11:47:26 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of soriano.carlos@gmail.com '
#                   'designates 209.85.220.41 as permitted sender) '
#                   'client-ip=209.85.220.41;',
#   'size_estimate': 504873,
#   'subject': 'Screenshot 2020-03-24 at 1.47.02 PM',
#   'thread_id': '1710ddef6b905652'},
#  {'date': 'Tue, 24 Mar 2020 06:10:41 -0700',
#   'from_': '"iZotope, Inc." <izotope@news.izotope.com>',
#   'history_id': '5693679',
#   'internal_date': '1585055441000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'Label_15'],
#   'message_id': '1710caaf028bf11f',
#   'parts': [{'body_size': 2510,
#              'content_transfer_encoding': '8bit',
#              'content_type': 'text/plain; charset="utf-8"',
#              'mime_type': 'text/plain'},
#             {'body_size': 32748,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset="utf-8"',
#              'mime_type': 'text/html'}],
#   'received': 'from [35.166.8.133] ([35.166.8.133:23013] '
#               'helo=r44.news.izotope.com) by momentum02.or1.cpt.adobe.net '
#               '(envelope-from <bounce@news.izotope.com>) (ecelerity '
#               '4.2.31.59853 r(Core:4.2.31.1)) with ESMTP id '
#               'AD/E2-00617-B760A7E5; Tue, 24 Mar 2020 06:09:15 -0700',
#   'received_SPF': 'pass (google.com: domain of bounce@news.izotope.com '
#                   'designates 192.243.229.43 as permitted sender) '
#                   'client-ip=192.243.229.43;',
#   'size_estimate': 41706,
#   'subject': 'Mix & master like the pros',
#   'thread_id': '1710caaf028bf11f'},
#  {'date': 'Tue, 24 Mar 2020 13:00:00 +0000 (UTC)',
#   'from_': 'Medium Daily Digest <noreply@medium.com>',
#   'history_id': '5693912',
#   'internal_date': '1585054800000',
#   'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#   'message_id': '1710ca149cefbc3e',
#   'parts': [{'body_size': 17766,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=UTF-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 99619,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=UTF-8',
#              'mime_type': 'text/html'}],
#   'received': 'from MTgyMzE0NA (unknown) by ismtpd0013p1iad2.sendgrid.net (SG) '
#               'with HTTP id 5Gg1SIucQuSC4vATHv6MQQ Tue, 24 Mar 2020 '
#               '10:12:22.715 +0000 (UTC)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'bounces+1823144-4c20-shortpoet=gmail.com@email.medium.com '
#                   'designates 149.72.133.6 as permitted sender) '
#                   'client-ip=149.72.133.6;',
#   'size_estimate': 131011,
#   'subject': '6 Habits of Super Learners | Thomas Oppong in Personal Growth',
#   'thread_id': '1710ca149cefbc3e'},
#  {'date': 'Tue, 24 Mar 2020 06:00:00 -0400',
#   'from_': 'Eastern Mountain Sports <easternmountainsports@em.ems.com>',
#   'history_id': '5693527',
#   'internal_date': '1585044000000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:9k6mrgn81bgxtzxta2vk4sukktu91uyf-u@em.ems.com>, '
#                       '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/bzhgccuctjkcrmwhnkqfktnjwywzbch?td=Jk8__UgZ3y6qt3Htyr1e5AYnTTF6vsxKW4vjgS0r46WFfCG8gjQY3cY5xU1stHU6i43axsRyT8dpB30v_OrT1L-pNZvRNiJgbPjFG1hcGwYA62mQXo4IchMkJLP8NVcxE3REUesH31WAQpnyr6jWqXIv9y5WSOSyNM&tid=28384182514529978492965224816498163711986394156403100874919027654897519634410754>',
#   'message_id': '1710c0a717db161b',
#   'parts': [{'body_size': 875,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=utf-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 29614,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=utf-8',
#              'mime_type': 'text/html'}],
#   'received': 'from localhost (10.0.2.130) by ms157-045.bronto.com id '
#               'hf7esu2lr20r for <shortpoet@gmail.com>; Tue, 24 Mar 2020 '
#               '06:04:55 -0400 (envelope-from '
#               '<9k6mrgn81bgxtzxta2vk4sukktu91uyf-b@em.ems.com>)',
#   'received_SPF': 'pass (google.com: domain of '
#                   '9k6mrgn81bgxtzxta2vk4sukktu91uyf-b@em.ems.com designates '
#                   '69.166.157.45 as permitted sender) client-ip=69.166.157.45;',
#   'size_estimate': 38540,
#   'subject': '🔵Daily Deal: 60% OFF All EMS Techwick Vital Shirts',
#   'thread_id': '1710c0a717db161b'},
#  {'date': '24 Mar 2020 07:43:24 +0000',
#   'from_': '"Newegg.com" <Promo@promo.newegg.com>',
#   'history_id': '5693456',
#   'internal_date': '1585035804000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:unsubscribe-c6a99c572036e3bad51d8b4aa43f3e1b@promo.newegg.com?subject=Unsubscribe>',
#   'message_id': '1710b93c26812107',
#   'parts': [{'body_size': 4548,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=utf-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 26816,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=utf-8',
#              'mime_type': 'text/html'}],
#   'received': 'from nampmer24 (10.24.72.84) by p1-002128.promo.newegg.com id '
#               'hf6vmq2bq58l for <shortpoet@gmail.com>; Tue, 24 Mar 2020 '
#               '03:43:24 -0400 (envelope-from <Promo@promo.newegg.com>)',
#   'received_SPF': 'pass (google.com: domain of promo@promo.newegg.com '
#                   'designates 173.213.2.128 as permitted sender) '
#                   'client-ip=173.213.2.128;',
#   'size_estimate': 39398,
#   'subject': 'Score: $89.99 WD Red 4TB NAS Hard Drive',
#   'thread_id': '1710b93c26812107'},
#  {'date': 'Tue, 24 Mar 2020 03:06:21 +0000',
#   'from_': '"Brasil Brasil Cultural Center & Capoeira Batuque" '
#            '<capoeirabatuque.bbcc@gmail.com>',
#   'history_id': '5693341',
#   'internal_date': '1585019181000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'message_id': '1710a81582596aba',
#   'parts': [{'body_size': 800,
#              'content_type': 'text/plain; charset="us-ascii"',
#              'mime_type': 'text/plain'},
#             {'body_size': 11598,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset="utf-8"; format="fixed"',
#              'mime_type': 'text/html'}],
#   'received': 'from 127.0.0.1 (localhost [127.0.0.1]) by mail11.mcsignup.com '
#               '(Mailchimp) with ESMTP id 48mbk523GZz35jnyc for '
#               '<shortpoet@gmail.com>; Tue, 24 Mar 2020 03:06:21 +0000 (GMT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'bounce-mcsys.us2_2835378.b4a9752948-shortpoet=gmail.com@mail11.mcsignup.com '
#                   'designates 198.2.140.131 as permitted sender) '
#                   'client-ip=198.2.140.131;',
#   'size_estimate': 21037,
#   'subject': 'community: You are now unsubscribed',
#   'thread_id': '1710a81582596aba'},
#  {'date': 'Tue, 24 Mar 2020 02:49:48 +0000',
#   'from_': 'Twitter <info@twitter.com>',
#   'history_id': '5693027',
#   'internal_date': '1585018188000',
#   'label_ids': ['UNREAD', 'CATEGORY_SOCIAL', 'INBOX'],
#   'list_unsubscribe': '<https://twitter.com/i/u?t=1&listunsub=t&cn=ZmxleGlibGVfcmVjc18y&sig=da23e45287f58e99677dd1beda545b1cc2b9f83e&iid=e315196d8edb4c6799ac813ed275cc17&uid=762420025&nid=244+26&usbid=9>',
#   'message_id': '1710a72371818dd5',
#   'parts': [{'body_size': 4257,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=UTF-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 81373,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=UTF-8',
#              'mime_type': 'text/html'}],
#   'received': 'from spruce-goose-bc.twitter.com (spruce-goose-bc.twitter.com. '
#               '[199.59.150.98])        by mx.google.com with ESMTPS id '
#               'u11si12542038pfl.94.2020.03.23.19.49.49        for '
#               '<shortpoet@gmail.com>        (version=TLS1_2 '
#               'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Mon, '
#               '23 Mar 2020 19:49:49 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'n03453c0cbc-e315196d8edb4c67-shortpoet===gmail.com@bounce.twitter.com '
#                   'designates 199.59.150.98 as permitted sender) '
#                   'client-ip=199.59.150.98;',
#   'size_estimate': 97569,
#   'subject': '"Popular Science answers your COVID-19 questions" Moment',
#   'thread_id': '1710a72371818dd5'},
#  {'date': 'Tue, 24 Mar 2020 02:21:13 +0000 (GMT)',
#   'from_': 'Google <no-reply@accounts.google.com>',
#   'history_id': '5692846',
#   'internal_date': '1585016473000',
#   'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#   'message_id': '1710a580bdfa076e',
#   'parts': [{'body_size': 577,
#              'content_transfer_encoding': 'base64',
#              'content_type': 'text/plain; charset="UTF-8"; format=flowed; '
#                              'delsp=yes',
#              'mime_type': 'text/plain'},
#             {'body_size': 4579,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset="UTF-8"',
#              'mime_type': 'text/html'}],
#   'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#               '[209.85.220.73])        by mx.google.com with SMTPS id '
#               'n105sor10603205ota.115.2020.03.23.19.21.14        for '
#               '<shortpoet@gmail.com>        (Google Transport '
#               'Security);        Mon, 23 Mar 2020 19:21:14 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   '3mm55xggtcvccd-g3eanz11djcih.5dd5a3.1dbh6dgied3i5bz7a.1db@gaia.bounces.google.com '
#                   'designates 209.85.220.73 as permitted sender) '
#                   'client-ip=209.85.220.73;',
#   'size_estimate': 11051,
#   'subject': 'Security alert',
#   'thread_id': '1710a03f179e6156'},
#  {'date': 'Tue, 24 Mar 2020 01:29:11 +0000 (GMT)',
#   'from_': 'Google <no-reply@accounts.google.com>',
#   'history_id': '5692846',
#   'internal_date': '1585013351000',
#   'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#   'message_id': '1710a28684d3268d',
#   'parts': [{'body_size': 583,
#              'content_transfer_encoding': 'base64',
#              'content_type': 'text/plain; charset="UTF-8"; format=flowed; '
#                              'delsp=yes',
#              'mime_type': 'text/plain'},
#             {'body_size': 4585,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset="UTF-8"',
#              'mime_type': 'text/html'}],
#   'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#               '[209.85.220.73])        by mx.google.com with SMTPS id '
#               't203sor11701516qke.142.2020.03.23.18.29.12        for '
#               '<shortpoet@gmail.com>        (Google Transport '
#               'Security);        Mon, 23 Mar 2020 18:29:12 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   '3agj5xggtcq001-4r2ybnpp17065.t11tyr.p1z5u14621r6tznvy.p1z@gaia.bounces.google.com '
#                   'designates 209.85.220.73 as permitted sender) '
#                   'client-ip=209.85.220.73;',
#   'size_estimate': 11066,
#   'subject': 'Security alert',
#   'thread_id': '1710a03f179e6156'},
#  {'date': 'Tue, 24 Mar 2020 01:25:48 +0000 (GMT)',
#   'from_': 'Google <no-reply@accounts.google.com>',
#   'history_id': '5692846',
#   'internal_date': '1585013148000',
#   'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#   'message_id': '1710a25520d8c749',
#   'parts': [{'body_size': 582,
#              'content_transfer_encoding': 'base64',
#              'content_type': 'text/plain; charset="UTF-8"; format=flowed; '
#                              'delsp=yes',
#              'mime_type': 'text/plain'},
#             {'body_size': 4583,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset="UTF-8"',
#              'mime_type': 'text/html'}],
#   'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#               '[209.85.220.73])        by mx.google.com with SMTPS id '
#               'd12sor12261544qke.124.2020.03.23.18.25.50        for '
#               '<shortpoet@gmail.com>        (Google Transport '
#               'Security);        Mon, 23 Mar 2020 18:25:50 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   '3nmf5xggtcueqr-uhso1dffrxqwv.jrrjoh.frpvkruwsrhwjpdlo.frp@gaia.bounces.google.com '
#                   'designates 209.85.220.73 as permitted sender) '
#                   'client-ip=209.85.220.73;',
#   'size_estimate': 11057,
#   'subject': 'Security alert',
#   'thread_id': '1710a03f179e6156'},
#  {'date': 'Tue, 24 Mar 2020 00:49:21 +0000 (GMT)',
#   'from_': 'Google <no-reply@accounts.google.com>',
#   'history_id': '5692846',
#   'internal_date': '1585010961000',
#   'label_ids': ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX'],
#   'message_id': '1710a03f179e6156',
#   'parts': [{'body_size': 573,
#              'content_transfer_encoding': 'base64',
#              'content_type': 'text/plain; charset="UTF-8"; format=flowed; '
#                              'delsp=yes',
#              'mime_type': 'text/plain'},
#             {'body_size': 4571,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset="UTF-8"',
#              'mime_type': 'text/html'}],
#   'received': 'from mail-sor-f73.google.com (mail-sor-f73.google.com. '
#               '[209.85.220.73])        by mx.google.com with SMTPS id '
#               'z144sor20265660pfc.89.2020.03.23.17.49.22        for '
#               '<shortpoet@gmail.com>        (Google Transport '
#               'Security);        Mon, 23 Mar 2020 17:49:22 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   '3ell5xggtcamqr-uhsobdffrxqwv.jrrjoh.frpvkruwsrhwjpdlo.frp@gaia.bounces.google.com '
#                   'designates 209.85.220.73 as permitted sender) '
#                   'client-ip=209.85.220.73;',
#   'size_estimate': 11037,
#   'subject': 'Security alert',
#   'thread_id': '1710a03f179e6156'},
#  {'date': 'Tue, 24 Mar 2020 00:14:45 +0000',
#   'from_': '"Brasil Brasil Cultural Center & Capoeira Batuque" '
#            '<capoeirabatuque.bbcc@gmail.com>',
#   'history_id': '5693339',
#   'internal_date': '1585008885000',
#   'label_ids': ['CATEGORY_UPDATES', 'INBOX'],
#   'list_unsubscribe': '<https://brasilbrasil.us2.list-manage.com/unsubscribe?u=1c298dc70041213bba74d7f5c&id=6cf1e7b99a&e=8cd2f3c4fd&c=5e64a5d8e0>, '
#                       '<mailto:unsubscribe-mc.us2_1c298dc70041213bba74d7f5c.5e64a5d8e0-8cd2f3c4fd@mailin.mcsv.net?subject=unsubscribe>',
#   'message_id': '17109e4decb71f2f',
#   'parts': [{'body_size': 2034,
#              'content_type': 'text/plain; charset="us-ascii"',
#              'mime_type': 'text/plain'},
#             {'body_size': 42544,
#              'content_type': 'text/html; charset="us-ascii"',
#              'mime_type': 'text/html'}],
#   'received': 'from localhost (localhost [127.0.0.1]) by '
#               'mail115.wdc01.mcdlv.net (Mailchimp) with ESMTP id '
#               '48mWwM2Cx3z7lmJcj for <shortpoet@gmail.com>; Tue, 24 Mar 2020 '
#               '00:14:59 +0000 (GMT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'bounce-mc.us2_2835378.1365565-8cd2f3c4fd@mail115.wdc01.mcdlv.net '
#                   'designates 205.201.129.115 as permitted sender) '
#                   'client-ip=205.201.129.115;',
#   'size_estimate': 50598,
#   'subject': 'Links to All Adult Capoeira Classes with Mestre Amen throughout '
#              'the week',
#   'thread_id': '17109e4decb71f2f'},
#  {'date': 'Tue, 24 Mar 2020 00:02:35 +0000',
#   'from_': '"Brasil Brasil Cultural Center & Capoeira Batuque" '
#            '<capoeirabatuque.bbcc@gmail.com>',
#   'history_id': '5692844',
#   'internal_date': '1585008155000',
#   'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#   'list_unsubscribe': '<https://brasilbrasil.us2.list-manage.com/unsubscribe?u=1c298dc70041213bba74d7f5c&id=6cf1e7b99a&e=8cd2f3c4fd&c=3516e47995>, '
#                       '<mailto:unsubscribe-mc.us2_1c298dc70041213bba74d7f5c.3516e47995-8cd2f3c4fd@mailin.mcsv.net?subject=unsubscribe>',
#   'message_id': '17109d975d786a40',
#   'parts': [{'body_size': 1426,
#              'content_type': 'text/plain; charset="us-ascii"',
#              'mime_type': 'text/plain'},
#             {'body_size': 40406,
#              'content_type': 'text/html; charset="us-ascii"',
#              'mime_type': 'text/html'}],
#   'received': 'from localhost (localhost [127.0.0.1]) by '
#               'mail115.wdc01.mcdlv.net (Mailchimp) with ESMTP id '
#               '48mWfG0KRGz7lmcp4 for <shortpoet@gmail.com>; Tue, 24 Mar 2020 '
#               '00:02:46 +0000 (GMT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'bounce-mc.us2_2835378.1365549-8cd2f3c4fd@mail115.wdc01.mcdlv.net '
#                   'designates 205.201.129.115 as permitted sender) '
#                   'client-ip=205.201.129.115;',
#   'size_estimate': 47798,
#   'subject': 'Samba with Ana ONLINE LINKS HERE',
#   'thread_id': '17109d975d786a40'},
#  {'date': 'Mon, 23 Mar 2020 18:00:00 -0400',
#   'from_': 'Eastern Mountain Sports <easternmountainsports@em.ems.com>',
#   'history_id': '5692330',
#   'internal_date': '1585000800000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:h2bm38be44d8x7kca2169vxufo47cuyf-u@em.ems.com>, '
#                       '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/aosuarredcxzysqvtwvnzbxsdybjbjb?td=4lNIEwTbwycIOq7PFvcP6QE5VqAOusMMkPAx2aGuqmuNf8wjpEsZAnYCTC8kphXyCSvhdVng9oVXxMmRbunbzu1ggh8E2_-zSFtMUawg2zUwrwOGeYUFFtOUgcOfStIsRvV1KLEISeyp8rTHzEe9RtXyI2b8Q7-CzS&tid=23390422374529978492965224838942444356477070271257088774780659352032037690404098>',
#   'message_id': '171096d47778ce36',
#   'parts': [{'body_size': 875,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=utf-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 34574,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=utf-8',
#              'mime_type': 'text/html'}],
#   'received': 'from localhost (10.0.2.105) by ms157-045.bronto.com id '
#               'hf4p802lr205 for <shortpoet@gmail.com>; Mon, 23 Mar 2020 '
#               '18:01:17 -0400 (envelope-from '
#               '<h2bm38be44d8x7kca2169vxufo47cuyf-b@em.ems.com>)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'h2bm38be44d8x7kca2169vxufo47cuyf-b@em.ems.com designates '
#                   '69.166.157.45 as permitted sender) client-ip=69.166.157.45;',
#   'size_estimate': 43770,
#   'subject': '💧Water Bottles from Hydro Flask, Yeti, Camelbak & MORE',
#   'thread_id': '171096d47778ce36'},
#  {'date': 'Mon, 23 Mar 2020 14:47:18 -0700',
#   'from_': 'Google Cloud Platform <CloudPlatform-noreply@google.com>',
#   'history_id': '5692843',
#   'internal_date': '1585000038000',
#   'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#   'message_id': '171095d405bd9749',
#   'parts': [{'body_size': 5973,
#              'content_transfer_encoding': 'base64',
#              'content_type': 'text/plain; charset="UTF-8"; format=flowed; '
#                              'delsp=yes',
#              'mime_type': 'text/plain'},
#             {'body_size': 56327,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset="UTF-8"',
#              'mime_type': 'text/html'}],
#   'received': 'from mail-sor-f69.google.com (mail-sor-f69.google.com. '
#               '[209.85.220.69])        by mx.google.com with SMTPS id '
#               'r85sor11968244ilb.54.2020.03.23.14.47.18        for '
#               '<shortpoet@gmail.com>        (Google Transport '
#               'Security);        Mon, 23 Mar 2020 14:47:18 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
# ...
#   'size_estimate': 19370,
#   'subject': 'Paid Sick Leave for All U.S. Workers.',
#   'thread_id': '170f80c352ca6447'},
#  {'date': 'Fri, 20 Mar 2020 11:23:58 +0000',
#   'from_': 'Groupon <noreply@r.groupon.com>',
#   'history_id': '5686960',
#   'internal_date': '1584703438000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:eb5d3420-23d3-11e2-86db-00259069d5fe@unsub.r.groupon.com?subject=ZWI1ZDM0MjAtMjNkMy0xMWUyLTg2ZGItMDAyNTkwNjlkNWZlOmJhdGNoOjBlOGFjMjUxLTkwOTUtNDA5NC1hNTQ3LWEyZGJkZmNiZGQ2YV8wXzIwMjAwMzIwOm51bGw6VVM=>',
#   'message_id': '170f7af8048b0804',
#   'parts': [],
#   'received': 'from mta409s1.r.groupon.com (mta409s1.r.groupon.com. '
#               '[50.115.211.109])        by mx.google.com with ESMTPS id '
#               'a18si4184217pfh.186.2020.03.20.04.23.58        for '
#               '<shortpoet@gmail.com>        (version=TLS1_2 '
#               'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Fri, '
#               '20 Mar 2020 04:23:58 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'eb5d3420-23d3-11e2-86db-00259069d5fe@bounce.r.groupon.com '
#                   'designates 50.115.211.109 as permitted sender) '
#                   'client-ip=50.115.211.109;',
#   'size_estimate': 33597,
#   'subject': "Happy Spring! 🌸 Here's 40% OFF On Us!",
#   'thread_id': '170f7af8048b0804'},
#  {'date': 'Fri, 20 Mar 2020 06:00:00 -0400',
#   'from_': 'Eastern Mountain Sports <easternmountainsports@em.ems.com>',
#   'history_id': '5686895',
#   'internal_date': '1584698400000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:9uyjp6sgtw7szvarvqmzmy49w7vmwuyf-u@em.ems.com>, '
#                       '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/awkckqnicqmpybyoobryfrkjjfkfbfp?td=Tlw1bcDnbtfX2dgsHCy7oA_rUU95ezB_63PFBIujrGewldF6yUzILOkiOzs1lVexYVKKDzZx5GIPP1j5PBBJRs1Z0IF7fFqOWGoTrbYG0NNutxRhZsSUM5DAP8H9V_zbS39yVXJ_WHfq0gKSyKEcSsJFIU4fJHUqjh&tid=16323239614529978492965224801894839351776012197711881988936504947959067603871489>',
#   'message_id': '170f776a3c789d1b',
#   'parts': [{'body_size': 875,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=utf-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 28010,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=utf-8',
#              'mime_type': 'text/html'}],
#   'received': 'from localhost (10.0.5.34) by ms157-045.bronto.com id '
#               'heick02lr20r for <shortpoet@gmail.com>; Fri, 20 Mar 2020 '
#               '06:06:44 -0400 (envelope-from '
#               '<9uyjp6sgtw7szvarvqmzmy49w7vmwuyf-b@em.ems.com>)',
#   'received_SPF': 'pass (google.com: domain of '
#                   '9uyjp6sgtw7szvarvqmzmy49w7vmwuyf-b@em.ems.com designates '
#                   '69.166.157.45 as permitted sender) client-ip=69.166.157.45;',
#   'size_estimate': 36747,
#   'subject': '>>> 20% OFF EVERYTHING <<<',
#   'thread_id': '170f776a3c789d1b'},
#  {'date': '20 Mar 2020 07:39:37 +0000',
#   'from_': '"Newegg.com" <Promo@promo.newegg.com>',
#   'history_id': '5686827',
#   'internal_date': '1584689977000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:unsubscribe-ae03d6968f481d5f785ac1b5f41f7302@promo.newegg.com?subject=Unsubscribe>',
#   'message_id': '170f6f663dfe6c43',
#   'parts': [{'body_size': 4471,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=utf-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 24975,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=utf-8',
#              'mime_type': 'text/html'}],
#   'received': 'from nampmer26 (10.24.72.86) by p1-002125.promo.newegg.com id '
#               'hehs6m2bq58s for <shortpoet@gmail.com>; Fri, 20 Mar 2020 '
#               '03:39:37 -0400 (envelope-from <Promo@promo.newegg.com>)',
#   'received_SPF': 'pass (google.com: domain of promo@promo.newegg.com '
#                   'designates 173.213.2.125 as permitted sender) '
#                   'client-ip=173.213.2.125;',
#   'size_estimate': 37224,
#   'subject': 'Feel the Power $219.99 Intel Core i5-9600K 6-Core 3.7GHz Desktop '
#              'Processor',
#   'thread_id': '170f6f663dfe6c43'},
#  {'date': 'Fri, 20 Mar 2020 05:15:58 +0000',
#   'from_': 'X-Mirage <x-mirage@x-mirage.com>',
#   'history_id': '5686648',
#   'internal_date': '1584681358000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<http://news.x-mirage.com/unsubscribe/c9glAJSAXYE2ABSvtWPPVUsF9oS2EQsagveHaHYhWmU/NOhdveOr892DZS1GAE2n7q0g/0UFGt64DNEXGrtkkirTinw>',
#   'message_id': '170f65e989c747bf',
#   'parts': [],
#   'received': 'from a11-68.smtp-out.amazonses.com '
#               '(a11-68.smtp-out.amazonses.com. [54.240.11.68])        by '
#               'mx.google.com with ESMTPS id '
#               'd57si2714933qtc.60.2020.03.19.22.15.59        for '
#               '<shortpoet@gmail.com>        (version=TLS1_2 '
#               'cipher=ECDHE-RSA-AES128-SHA bits=128/128);        Thu, 19 Mar '
#               '2020 22:15:59 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   '01000170f65e9668-016eb9bf-f55d-4334-a48e-91244e2d3d7a-000000@amazonses.com '
#                   'designates 54.240.11.68 as permitted sender) '
#                   'client-ip=54.240.11.68;',
#   'size_estimate': 18952,
#   'subject': 'NordPass Password Manager: 1-Yr Subscription (49% off) - Get an '
#              'extra 15% off with promo code: SPRINGSAVE15',
#   'thread_id': '170f65e989c747bf'},
#  {'date': 'Fri, 20 Mar 2020 02:23:09 +0000',
#   'from_': 'Groupon Goods <noreply@r.groupon.com>',
#   'history_id': '5686584',
#   'internal_date': '1584670989000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:eb5d3420-23d3-11e2-86db-00259069d5fe@unsub.r.groupon.com?subject=ZWI1ZDM0MjAtMjNkMy0xMWUyLTg2ZGItMDAyNTkwNjlkNWZlOmJhdGNoOjI4N2QxMDNhLTY2NTgtNDU0Ny1iMDAzLTM2ZTRkMDIxMzg5N18wXzIwMjAwMzE5X3RyZWF0bWVudDA6bnVsbDpVUw==>',
#   'message_id': '170f5c063e4bff55',
#   'parts': [],
#   'received': 'from mta433s1.r.groupon.com (mta433s1.r.groupon.com. '
#               '[50.115.211.133])        by mx.google.com with ESMTPS id '
#               'q5si3048030pjq.18.2020.03.19.19.23.10        for '
#               '<shortpoet@gmail.com>        (version=TLS1_2 '
#               'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Thu, '
#               '19 Mar 2020 19:23:10 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'eb5d3420-23d3-11e2-86db-00259069d5fe@bounce.r.groupon.com '
#                   'designates 50.115.211.133 as permitted sender) '
#                   'client-ip=50.115.211.133;',
#   'size_estimate': 177519,
#   'subject': "Apple iPad mini 2 WiFi Tablet, Sociology Women's Weather Boots, "
#              "Women's Car Coat with Scarf & More",
#   'thread_id': '170f5c063e4bff55'},
#  {'date': 'Fri, 20 Mar 2020 01:54:25 +0000 (UTC)',
#   'from_': 'MedMen <hello@medmen.com>',
#   'history_id': '5686531',
#   'internal_date': '1584669265000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'message_id': '170f5a61326532c5',
#   'parts': [],
#   'received': 'from ip-10-0-1-240.ec2.internal (unknown) by '
#               'ismtpd0090p1mdw1.sendgrid.net (SG) with ESMTP id '
#               'yDFSvaKkQkCSG9q3iANxXA for <sendgrid@clutch.com>; Fri, 20 Mar '
#               '2020 01:53:00.098 +0000 (UTC)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'bounces+7069921-ea2c-shortpoet=gmail.com@em1.medmen.com '
#                   'designates 198.37.145.71 as permitted sender) '
#                   'client-ip=198.37.145.71;',
#   'size_estimate': 125921,
#   'subject': 'An Update on Our Status of Operations',
#   'thread_id': '170f5a61326532c5'},
#  {'date': 'Fri, 20 Mar 2020 12:02:12 +1100',
#   'from_': 'The Broad <info@thebroad.org>',
#   'history_id': '5686449',
#   'internal_date': '1584666132000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<http://unsub.cmail20.com/t/d-u-mjydidk-yduyulljkh/>, '
#                       '<mailto:unsubscribe-mjydidk2yduyulljkh2d-7974D761@cmail20.com?subject=Unsubscribe>',
#   'message_id': '170f578cb62e4410',
#   'parts': [{'body_size': 5180,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset="utf-8"',
#              'mime_type': 'text/plain'},
#             {'body_size': 40549,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset="utf-8"',
#              'mime_type': 'text/html'}],
#   'received': 'from mx106.a.outbound.createsend.com '
#               '(mx106.a.outbound.createsend.com. [203.55.21.106])        by '
#               'mx.google.com with ESMTPS id '
#               't136si3073678pgb.39.2020.03.19.18.04.58        for '
#               '<shortpoet@gmail.com>        (version=TLS1_2 '
#               'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Thu, '
#               '19 Mar 2020 18:04:59 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'thebroad-mjydidk1yduyulljkh1d@cmail20.com designates '
#                   '203.55.21.106 as permitted sender) client-ip=203.55.21.106;',
#   'size_estimate': 53066,
#   'subject': 'Find inspiration and stay connected with The Broad online',
#   'thread_id': '170f578cb62e4410'},
#  {'date': 'Thu, 19 Mar 2020 17:30:44 -0600',
#   'from_': 'Hulu <hulu@hulumail.com>',
#   'history_id': '5686378',
#   'internal_date': '1584660644000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:leave-fd7f10781a3c402029-fe2212707c63017a751374-fe86107271620d7a7c-fe9515707360007972-ff2612797663@leave.hulumail.com>',
#   'message_id': '170f5260c7b763cb',
#   'parts': [{'body_size': 6426,
#              'content_transfer_encoding': '8bit',
#              'content_type': 'text/plain; charset="utf-8"',
#              'mime_type': 'text/plain'},
#             {'body_size': 70831,
#              'content_transfer_encoding': '8bit',
#              'content_type': 'text/html; charset="utf-8"',
#              'mime_type': 'text/html'}],
#   'received': 'by mta17.hulumail.com id heg0oo2fmd4t for '
#               '<shortpoet@gmail.com>; Thu, 19 Mar 2020 23:30:44 +0000 '
#               '(envelope-from '
#               '<bounce-48_HTML-609757074-4246979-1064447-6937@bounce.hulumail.com>)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'bounce-48_html-609757074-4246979-1064447-6937@bounce.hulumail.com '
#                   'designates 13.111.102.14 as permitted sender) '
#                   'client-ip=13.111.102.14;',
#   'size_estimate': 81870,
#   'subject': "Hulu Has Whatever You're Feeling",
#   'thread_id': '170f5260c7b763cb'},
#  {'date': 'Thu, 19 Mar 2020 18:00:00 -0400',
#   'from_': 'Eastern Mountain Sports <easternmountainsports@em.ems.com>',
#   'history_id': '5686308',
#   'internal_date': '1584655200000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<mailto:j5563e4rmkmek840oc9lawj10x5nmuyf-u@em.ems.com>, '
#                       '<http://em.ems.com/public/webform/render_form/default/be9b135894496ff83ad10d00032d4117/unsub/khtpbjcz4fk61gd3fie6xx5mxioqf/bxuoytxkqbtmxdlqsczugfxnzgehbeg?td=LzD63GPtrnKcPHRdsoX4oAzeVlkU5UXKB0ve3oo6oMN8OKj1iZX9BiiHPEPWG00JiLgdRfAIT1AmhWRiVgzwaD-XYlSzcz_o8pJjsHDopcbwnZYyKnHQ1xqjT2xZ0TmBI0i7-AoLRcu0DwjIQXN8RlVf5t3ZddpQCR&tid=37088725374529978492965224834441019313497889283189739522650782414603883529891074>',
#   'message_id': '170f4d84cb38b7a2',
#   'parts': [{'body_size': 875,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset=utf-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 31158,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=utf-8',
#              'mime_type': 'text/html'}],
#   'received': 'from localhost (10.0.4.169) by ms157-045.bronto.com id '
#               'hefmq82lr20q for <shortpoet@gmail.com>; Thu, 19 Mar 2020 '
#               '18:01:15 -0400 (envelope-from '
#               '<j5563e4rmkmek840oc9lawj10x5nmuyf-b@em.ems.com>)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'j5563e4rmkmek840oc9lawj10x5nmuyf-b@em.ems.com designates '
#                   '69.166.157.45 as permitted sender) client-ip=69.166.157.45;',
#   'size_estimate': 40087,
#   'subject': 'Up to 50% OFF EMS Pants',
#   'thread_id': '170f4d84cb38b7a2'},
#  {'date': 'Thu, 19 Mar 2020 22:06:13 +0000',
#   'from_': 'INFOLIST <jeffgund@infolist.com>',
#   'history_id': '5686254',
#   'internal_date': '1584655573000',
#   'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX'],
#   'list_unsubscribe': '<https://INFOLIST.us15.list-manage.com/unsubscribe?u=83c3401736a63b44b3f05de50&id=a19f01dc9f&e=2756a70a0a&c=abfe75b361>, '
#                       '<mailto:unsubscribe-mc.us15_83c3401736a63b44b3f05de50.abfe75b361-2756a70a0a@mailin.mcsv.net?subject=unsubscribe>',
#   'message_id': '170f4d5b0ab03e36',
#   'parts': [{'body_size': 8498,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/plain; charset="utf-8"; format="fixed"',
#              'mime_type': 'text/plain'},
#             {'body_size': 101498,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset="utf-8"',
#              'mime_type': 'text/html'}],
#   'received': 'from localhost (localhost [127.0.0.1]) by '
#               'mail78.sea41.rsgsv.net (Mailchimp) with ESMTP id '
#               '48k1Fp4GHhz6CQZZ2 for <shortpoet@gmail.com>; Thu, 19 Mar 2020 '
#               '22:06:22 +0000 (GMT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'bounce-mc.us15_72942930.485587-2756a70a0a@mail78.sea41.rsgsv.net '
#                   'designates 148.105.13.78 as permitted sender) '
#                   'client-ip=148.105.13.78;',
#   'size_estimate': 124860,
#   'subject': 'INFOLIST:\xa0 Win Up to $10,000 -\xa0Casting Contestants for New '
#              'Game Show for the Game Show Network!',
#   'thread_id': '170f4d5b0ab03e36'},
#  {'date': 'Thu, 19 Mar 2020 21:57:22 +0000',
#   'from_': 'Twitter <notify@twitter.com>',
#   'history_id': '5690029',
#   'internal_date': '1584655042000',
#   'label_ids': ['UNREAD', 'CATEGORY_UPDATES', 'INBOX'],
#   'list_unsubscribe': '<https://twitter.com/i/u?t=1&listunsub=t&cn=YWN0aXZpdHlfZGlnZXN0X3dpdGhfaGVhZGxpbmVfY2hhbmdl&sig=382eb5798694be3b1a04437ce44135857f31efa4&iid=2e887b48fb9d4364988adc7fa9a02c56&uid=762420025&nid=244+26&usbid=16>',
#   'message_id': '170f4cd092a0b833',
#   'parts': [{'body_size': 806,
#              'content_transfer_encoding': '7bit',
#              'content_type': 'text/plain; charset=UTF-8',
#              'mime_type': 'text/plain'},
#             {'body_size': 16718,
#              'content_transfer_encoding': 'quoted-printable',
#              'content_type': 'text/html; charset=UTF-8',
#              'mime_type': 'text/html'}],
#   'received': 'from spruce-goose-aa.twitter.com (spruce-goose-aa.twitter.com. '
#               '[199.59.150.70])        by mx.google.com with ESMTPS id '
#               'q80si2824823pfc.252.2020.03.19.14.57.22        for '
#               '<shortpoet@gmail.com>        (version=TLS1_2 '
#               'cipher=ECDHE-RSA-AES128-GCM-SHA256 bits=128/128);        Thu, '
#               '19 Mar 2020 14:57:22 -0700 (PDT)',
#   'received_SPF': 'pass (google.com: domain of '
#                   'n0340ae2eb0-2e887b48fb9d4364-shortpoet===gmail.com@bounce.twitter.com '
#                   'designates 199.59.150.70 as permitted sender) '
#                   'client-ip=199.59.150.70;',
#   'size_estimate': 25629,
#   'subject': '@Carl8sSoriano, check out the notifications you have on Twitter',
#   'thread_id': '170f4cd092a0b833'}]

# %%
for i, m in enumerate(messages):
    try:
        if len(m['list_unsubscribe']) < 10:
            print(m)
    except:
        print(i, m['message_id'])
# Out:
# 9 1710f37bea23792c
# 10 1710f35d099f1ae1
# 11 1710f16f868f42d0
# 15 1710e8e0c39d7669
# 18 1710e3361e3e7719
# 20 1710ddef6b905652
# 21 1710caaf028bf11f
# 25 1710a81582596aba
# 27 1710a580bdfa076e
# 28 1710a28684d3268d
# 29 1710a25520d8c749
# 30 1710a03f179e6156
# 34 171095d405bd9749
# 37 17108a51fc9be488
# 38 171089c798c277f6
# 45 171048d30b80f542
# 50 17103b1586774a9c
# 51 17103b070e0f3872
# 53 17103a470f5a8076
# 55 1710393d23ba5a3b
# 56 171038bbada38199
# 66 170fe60536dbd8eb
# 67 170fe27f22f37136
# 69 170fdd74940ecd22
# 71 170fd99b758c5b0f
# 83 170f97a220ec749c
# 95 170f5a61326532c5

# %%
messages[3]['list_unsubscribe']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-7d70a6d899d5> in <module>
# ----> 1 messages[3]['list_unsubscribe']
#
# KeyError: 'list_unsubscribe'
